# %%
import pandas as pd

# %%
df_2020 = pd.read_csv("./tmdb_v3_output/tmdb_2020.csv")
df_2020.head()
# Out:
#                 title release_date   type  runtime  season_count  \
# 0    Stepmom's Desire   2020-05-29  movie     78.0           NaN
# 1        Pizza Dare 1   2020-04-10  movie     68.0           NaN
# 2          Bosomy Mom   2020-05-06  movie     69.0           NaN
# 3  Sonic the Hedgehog   2020-02-12  movie     99.0           NaN
# 4                  12   2020-09-04  movie     15.0           NaN
#
#    episode_count                                    genre       director  \
# 0            NaN                           Drama, Romance  Lee Dong-Joon
# 1            NaN                                  Romance   Kong Ja-kwan
# 2            NaN                           Drama, Romance  Lee Dong-Joon
# 3            NaN  Action, Science Fiction, Comedy, Family    Jeff Fowler
# 4            NaN                                      NaN  Salih Hashwan
#
#                                                 cast country language  \
# ...

# %%
df_2020.isnull().sum()
# Out:
# title                     0
# release_date              0
# type                      0
# runtime                5900
# season_count          10000
# episode_count         10002
# genre                  3871
# director               7949
# cast                   4456
# country                1665
# language                  0
# production_company     9140
# synopsis               4656
# tags                  15174
# imdb_rating               0
# imdb_review_count         0
# dtype: int64

# %%
df_2020.shape
# Out:
# (19628, 16)

# %%
df_2021 = pd.read_csv("./tmdb_v3_output/tmdb_2021.csv")
#print(df_2021.head())
print(df_2021.shape)
print(df_2021.isnull().sum())
print(df_2021.describe())
# Out:
# (20000, 16)
# title                     1
# release_date              0
# type                      0
# runtime                5620
# season_count          10000
# episode_count         10000
# genre                  3142
# director               7832
# cast                   3826
# country                1068
# language                  0
# production_company     8345
# synopsis               4758
# tags                  15648
# imdb_rating               0
# imdb_review_count         0
# dtype: int64
#             runtime  season_count  episode_count   imdb_rating  \
# count  14380.000000  10000.000000   10000.000000  20000.000000
# mean      64.911961      1.434500      18.731400      3.562157
# std       42.188289      1.299107      44.500754      3.448547
# min        1.000000      1.000000       0.000000      0.000000
# 25%       30.000000      1.000000       4.000000      0.000000
# 50%       61.000000      1.000000       8.000000      4.000000
# ...

# %%
df_2022 = pd.read_csv("./tmdb_v3_output/tmdb_2022.csv")
#print(df_2022.head())
print(df_2022.shape)
print(df_2022.isnull().sum())
print(df_2022.describe())
# Out:
# (20000, 16)
# title                     0
# release_date              0
# type                      0
# runtime                6328
# season_count          10000
# episode_count         10000
# genre                  2862
# director               7682
# cast                   3801
# country                  27
# language                  0
# production_company     7564
# synopsis               4463
# tags                  15761
# imdb_rating               0
# imdb_review_count         0
# dtype: int64
#             runtime  season_count  episode_count   imdb_rating  \
# count  13672.000000   10000.00000   10000.000000  20000.000000
# mean      70.221621       1.33430      17.008300      3.757108
# std       44.380885       1.09739      37.094377      3.421635
# min        1.000000       1.00000       0.000000      0.000000
# 25%       38.000000       1.00000       4.000000      0.000000
# 50%       75.000000       1.00000       8.000000      4.600000
# ...

# %%
df_2023 = pd.read_csv("./tmdb_v3_output/tmdb_2023.csv")
#print(df_2023.head())
print(df_2023.shape)
print(df_2023.isnull().sum())
print(df_2023.describe())
# Out:
# (20000, 16)
# title                     0
# release_date              0
# type                      0
# runtime                7876
# season_count          10000
# episode_count         10000
# genre                  3042
# director               7833
# cast                   4081
# country                  32
# language                  0
# production_company     7299
# synopsis               4868
# tags                  15753
# imdb_rating               0
# imdb_review_count         0
# dtype: int64
#             runtime  season_count  episode_count   imdb_rating  \
# count  12124.000000   10000.00000   10000.000000  20000.000000
# mean      74.731937       1.22770      14.826400      3.545653
# std       99.084495       0.79556      28.791849      3.494307
# min        1.000000       1.00000       0.000000      0.000000
# 25%       41.000000       1.00000       3.000000      0.000000
# 50%       82.000000       1.00000       8.000000      4.000000
# ...

# %%
df_2024 = pd.read_csv("./tmdb_v3_output/tmdb_2024.csv")
#print(df_2024.head())
print(df_2024.shape)
print(df_2024.isnull().sum())
print(df_2024.describe())
# Out:
# (19996, 16)
# title                     0
# release_date              0
# type                      0
# runtime                8694
# season_count           9998
# episode_count          9998
# genre                  3732
# director               7708
# cast                   4436
# country                  35
# language                  0
# production_company     7647
# synopsis               5211
# tags                  15562
# imdb_rating               0
# imdb_review_count         0
# dtype: int64
#             runtime  season_count  episode_count   imdb_rating  \
# count  11302.000000   9998.000000    9998.000000  19996.000000
# mean      75.398602      1.101120      12.026605      3.127304
# std       45.210434      0.542001      21.657405      3.554886
# min        1.000000      1.000000       0.000000      0.000000
# 25%       42.000000      1.000000       2.000000      0.000000
# 50%       84.000000      1.000000       6.000000      0.000000
# ...

# %%
df_2025 = pd.read_csv("./tmdb_v3_output/tmdb_2025.csv")
#print(df_2025.head())
print(df_2025.shape)
print(df_2025.isnull().sum())
print(df_2025.describe())
# Out:
# (15030, 16)
# title                     0
# release_date              0
# type                      0
# runtime                6639
# season_count           9997
# episode_count         10004
# genre                  2661
# director               4346
# cast                   3031
# country                  55
# language                  0
# production_company     6053
# synopsis               3357
# tags                  11131
# imdb_rating               0
# imdb_review_count         0
# dtype: int64
#            runtime  season_count  episode_count   imdb_rating  \
# count  8391.000000   5033.000000    5026.000000  15030.000000
# mean     67.725063      1.039539      10.516315      1.889208
# std      48.960981      0.417505      16.413083      3.284875
# min       1.000000      0.000000       0.000000      0.000000
# 25%      20.000000      1.000000       1.000000      0.000000
# 50%      78.000000      1.000000       6.000000      0.000000
# ...

# %%
df_2025.sort_values(by='release_date', ascending=False).head(10)
# Out:
#                         title release_date   type  runtime  season_count  \
# 15029                 我在天庭收废品   2025-12-31     tv      NaN           1.0
# 6575              ek • stasis   2025-12-31  movie     20.0           NaN
# 11145             Lonely Hero   2025-12-31     tv      NaN           1.0
# 9883   THE TRUE EDGE OF TIME.   2025-12-31  movie      NaN           NaN
# 14413                   大周斩妖人   2025-12-31     tv      NaN           1.0
# 14460                      凡应   2025-12-31     tv      NaN           1.0
# 9608           Superjuffie II   2025-12-31  movie     84.0           NaN
# 9445            Furious Times   2025-12-31  movie      NaN           NaN
# 9293          Hand of Justice   2025-12-31  movie      NaN           NaN
# 2169           Cost of Living   2025-12-31  movie     99.0           NaN
#
#        episode_count                   genre                         director  \
# 15029            1.0                     NaN                              NaN
# ...

# %%
df_2026 = pd.read_csv("./tmdb_v3_output/tmdb_2026.csv")
#print(df_2026.head())
print(df_2026.shape)
print(df_2026.isnull().sum())
print(df_2026.describe())
# Out:
# (408, 16)
# title                   0
# release_date            0
# type                    0
# runtime               311
# season_count          376
# episode_count         376
# genre                  78
# director               62
# cast                  107
# country                 6
# language                0
# production_company    122
# synopsis               87
# tags                  261
# imdb_rating             0
# imdb_review_count       0
# dtype: int64
#           runtime  season_count  episode_count  imdb_rating  imdb_review_count
# count   97.000000          32.0      32.000000        408.0              408.0
# mean    75.989691           1.0       1.906250          0.0                0.0
# std     51.319972           0.0       2.855209          0.0                0.0
# min      6.000000           1.0       1.000000          0.0                0.0
# 25%     25.000000           1.0       1.000000          0.0                0.0
# ...

# %%
df_2026.head()
# Out:
#                                     title release_date   type  runtime  \
# 0                      Avengers: Doomsday   2026-12-18  movie      NaN
# 1  28 Years Later Part 2: The Bone Temple   2026-01-06  movie      NaN
# 2                                 Shrek 5   2026-12-23  movie      NaN
# 3                             Toy Story 5   2026-06-17  movie      NaN
# 4               Spider-Man: Brand New Day   2026-07-30  movie      NaN
#
#    season_count  episode_count                               genre  \
# 0           NaN            NaN                     Science Fiction
# 1           NaN            NaN   Horror, Science Fiction, Thriller
# 2           NaN            NaN  Animation, Family, Comedy, Fantasy
# 3           NaN            NaN           Animation, Family, Comedy
# 4           NaN            NaN  Science Fiction, Action, Adventure
#
#                     director  \
# 0   Joe Russo, Anthony Russo
# 1                Nia DaCosta
# 2  Walt Dohrn, Conrad Vernon
# ...
