# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # 기본 데이터 확인

# %%
df_2020 = pd.read_csv("./tmdb_v3_output/tmdb_2020.csv")
df_2020.head()
# Out:
#                 title release_date   type  runtime  season_count  \
# 0    Stepmom's Desire   2020-05-29  movie     78.0           NaN
# 1        Pizza Dare 1   2020-04-10  movie     68.0           NaN
# 2          Bosomy Mom   2020-05-06  movie     69.0           NaN
# 3  Sonic the Hedgehog   2020-02-12  movie     99.0           NaN
# 4                  12   2020-09-04  movie     15.0           NaN
#
#    episode_count                                    genre       director  \
# 0            NaN                           Drama, Romance  Lee Dong-Joon
# 1            NaN                                  Romance   Kong Ja-kwan
# 2            NaN                           Drama, Romance  Lee Dong-Joon
# 3            NaN  Action, Science Fiction, Comedy, Family    Jeff Fowler
# 4            NaN                                      NaN  Salih Hashwan
#
#                                                 cast country language  \
# 0                   Lee Soo, Tae Hee, James, Jung In      KR       ko
# 1  Yoo Jung, Yoon So-jung, Jin Si-ah, Baek Yoon-j...      KR       ko
# 2        Yoo Jung, Han Yi-seul, James, Shin Yeon-woo      KR       ko
# 3  Ben Schwartz, James Marsden, Tika Sumpter, Jim...      US       en
# 4                                                NaN      SA       ar
#
#                                   production_company  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Original Film, Blur Studio, Marza Animation Pl...
# 4                                                NaN
#
#                                             synopsis  \
# 0  Sang-jin, who was envious of her neighbor afte...
# 1  Seok, who wants to try perverted sex, pesters ...
# 2  Da-hee gets married to Min-soo who is older th...
# 3  Powered with incredible speed, Sonic The Hedge...
# 4                                      not there yet
#
#                                                 tags  imdb_rating  \
# 0                                           softcore        7.150
# 1                                           softcore        6.222
# 2                                           softcore        5.900
# 3  friendship, video game, san francisco, califor...        7.307
# 4                                                NaN        5.481
#
#    imdb_review_count
# 0                 20
# 1                  9
# 2                 11
# 3               9955
# 4                 53

# %%
df_2020.sort_values(by='title', ascending=True).head(10)
# Out:
#                                            title release_date   type  runtime  \
# 19                                        #Alive   2020-06-24  movie     98.0
# 11576  #CoupleChallenge – Das beste Team gewinnt   2020-12-08     tv     60.0
# 11352                              #FreeRayshawn   2020-04-13     tv     10.0
# 1756                         #FriendButMarried 2   2020-02-27  movie    104.0
# 13743                                  #HASHTALK   2020-01-06     tv      3.0
# 1015                             #HandballStrive   2020-07-24  movie    108.0
# 1040                                    #Iamhere   2020-02-05  movie    100.0
# 13920                   #Influencers: The Series   2020-11-18     tv      NaN
# 18122                              #JURIFUL_DAYS   2020-08-15     tv      NaN
# 10819                                  #Luimelia   2020-02-14     tv     30.0
#
#        season_count  episode_count                   genre       director  \
# 19              NaN            NaN          Action, Horror         Cho Il
# 11576           4.0           36.0                 Reality            NaN
# 11352           1.0           15.0            Drama, Crime            NaN
# 1756            NaN            NaN  Drama, Comedy, Romance  Rako Prijanto
# 13743           4.0           27.0                     NaN            NaN
# 1015            NaN            NaN           Comedy, Drama   Daigo Matsui
# 1040            NaN            NaN         Comedy, Romance  Eric Lartigau
# 13920           1.0            9.0                   Drama            NaN
# 18122           2.0           16.0                     NaN            NaN
# 10819           4.0           29.0           Comedy, Drama            NaN
#
#                                                     cast country language  \
# 19     Yoo Ah-in, Park Shin-hye, Lee Hyun-wook, Jin S...      KR       ko
# 11576                                                NaN     NaN       de
# 11352  Stephan James, Laurence Fishburne, Jasmine Cep...      US       en
# 1756   Adipati Dolken, Mawar Eva De Jongh, Vonny Corn...      ID       id
# 13743  Cho Mi-yeon, Minnie, Jeon So-yeon, Song Yuqi, ...      KR       ko
# 1015   Seishirou Katou, Kotaro Daigo, Aju Makita, Har...      JP       ja
# 1040   Alain Chabat, Bae Doona, Jules Sagot, Ilian Be...      FR       fr
# 13920  Chollo Sotiangco, Leon Eustaquio, Denjo Jose, ...     NaN       en
# 18122                                                NaN     NaN       en
# 10819  Carol Rovira, Paula Usero, Lucía Martín Abello...      ES       es
#
#                                       production_company  \
# 19     Lotte Entertainment, Zip Cinema, Perspective P...
# 11576                                                NaN
# 11352              Sony Pictures Television, Fuqua Films
# 1756                                     Falcon Pictures
# 13743                                                NaN
# 1015                              Grasshoppa!, ColorBird
# 1040   Rectangle Productions, Gaumont, France 2 Ciném...
# 13920                                                NaN
# 18122                                                NaN
# 10819                                         Atresmedia
#
#                                                 synopsis  \
# 19     As a grisly virus rampages a city, a lone man ...
# 11576                                                NaN
# 11352  Iraq war veteran Rayshawn takes shelter in his...
# 1756   As Ayu and Ditto finally transition from best ...
# 13743  A mini series focused on the behind the scenes...
# 1015   The school’s handball club is about to close d...
# 1040   Stéphane lives a quiet life as an eminent Fren...
# 13920  Rooted from the harsh society, and the indiffe...
# 18122  Vlog series following Juri of kpop group Rocke...
# 10819  A spin-off of Love in Difficult Times that foc...
#
#                                                     tags  imdb_rating  \
# 19     escape, alone, survival, drone, zombie, apartm...        7.225
# 11576                                                NaN        7.500
# 11352                                                NaN        7.200
# 1756                                                 NaN        6.200
# 13743                                                NaN        0.000
# 1015   sports, handball, social media, viral video, t...        7.000
# 1040                          korean, seoul, south korea        5.562
# 13920                                                NaN        1.000
# 18122                                                NaN        1.000
# 10819                                                NaN        5.700
#
#        imdb_review_count
# 19                  1892
# 11576                  2
# 11352                 13
# 1756                   9
# 13743                  0
# 1015                   2
# 1040                 210
# 13920                  1
# 18122                  1
# 10819                 16

# %%
df_2020.isnull().sum()
# Out:
# title                     0
# release_date              0
# type                      0
# runtime                5900
# season_count          10000
# episode_count         10002
# genre                  3871
# director               7949
# cast                   4456
# country                1665
# language                  0
# production_company     9140
# synopsis               4656
# tags                  15174
# imdb_rating               0
# imdb_review_count         0
# dtype: int64

# %% [markdown]
# # 2. 전처리 전처리_type

# %%
df_2020[df_2020['season_count'].isna() & df_2020['episode_count'].isna()].head(5)
# Out:
#                 title release_date   type  runtime  season_count  \
# 0    Stepmom's Desire   2020-05-29  movie     78.0           NaN
# 1        Pizza Dare 1   2020-04-10  movie     68.0           NaN
# 2          Bosomy Mom   2020-05-06  movie     69.0           NaN
# 3  Sonic the Hedgehog   2020-02-12  movie     99.0           NaN
# 4                  12   2020-09-04  movie     15.0           NaN
#
#    episode_count                                    genre       director  \
# 0            NaN                           Drama, Romance  Lee Dong-Joon
# 1            NaN                                  Romance   Kong Ja-kwan
# 2            NaN                           Drama, Romance  Lee Dong-Joon
# 3            NaN  Action, Science Fiction, Comedy, Family    Jeff Fowler
# 4            NaN                                      NaN  Salih Hashwan
#
#                                                 cast country language  \
# 0                   Lee Soo, Tae Hee, James, Jung In      KR       ko
# 1  Yoo Jung, Yoon So-jung, Jin Si-ah, Baek Yoon-j...      KR       ko
# 2        Yoo Jung, Han Yi-seul, James, Shin Yeon-woo      KR       ko
# 3  Ben Schwartz, James Marsden, Tika Sumpter, Jim...      US       en
# 4                                                NaN      SA       ar
#
#                                   production_company  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Original Film, Blur Studio, Marza Animation Pl...
# 4                                                NaN
#
#                                             synopsis  \
# 0  Sang-jin, who was envious of her neighbor afte...
# 1  Seok, who wants to try perverted sex, pesters ...
# 2  Da-hee gets married to Min-soo who is older th...
# 3  Powered with incredible speed, Sonic The Hedge...
# 4                                      not there yet
#
#                                                 tags  imdb_rating  \
# 0                                           softcore        7.150
# 1                                           softcore        6.222
# 2                                           softcore        5.900
# 3  friendship, video game, san francisco, califor...        7.307
# 4                                                NaN        5.481
#
#    imdb_review_count
# 0                 20
# 1                  9
# 2                 11
# 3               9955
# 4                 53

# %%
df_2020[df_2020['season_count'].isna() & df_2020['episode_count'].isna()].shape
# Out:
# (10000, 16)

# %%
df_2020['type'].value_counts(dropna=False)
# Out:
# type
# movie    10000
# tv        9628
# Name: count, dtype: int64

# %%
print(df_2020[df_2020['type'] == 'movie']['season_count'].value_counts(dropna=False))
print(df_2020[df_2020['type'] == 'movie']['episode_count'].value_counts(dropna=False))
# Out:
# season_count
# NaN    10000
# Name: count, dtype: int64
# episode_count
# NaN    10000
# Name: count, dtype: int64

# %%
print(df_2020[df_2020['type'] == 'tv']['season_count'].value_counts(dropna=False))
# Out:
# season_count
# 1.0     7522
# 2.0     1092
# 3.0      426
# 4.0      218
# 5.0      165
# 6.0      101
# 7.0       37
# 8.0       22
# 9.0       13
# 10.0      10
# 11.0       5
# 14.0       3
# 18.0       2
# 21.0       2
# 13.0       2
# 17.0       1
# 26.0       1
# 39.0       1
# 62.0       1
# 12.0       1
# 30.0       1
# 29.0       1
# 15.0       1
# Name: count, dtype: int64

# %%
print(df_2020[df_2020['type'] == 'tv']['episode_count'].value_counts(dropna=False))
# Out:
# episode_count
# 1.0       1879
# 6.0        745
# 8.0        613
# 10.0       559
# 4.0        545
#           ...
# 212.0        1
# 970.0        1
# 188.0        1
# 402.0        1
# 1247.0       1
# Name: count, Length: 250, dtype: int64

# %%
df_2020_1 = df_2020

# %%
# movie인 경우 season/episode count가 NaN이면 1로 채움
df_2020_1.loc[df_2020_1['type'] == 'movie', ['season_count', 'episode_count']] = df_2020_1.loc[df_2020_1['type'] == 'movie', ['season_count', 'episode_count']].fillna(1)
pd.set_option('display.max_columns', None)
df_2020_1.head()
# Out:
#                 title release_date   type  runtime  season_count  \
# 0    Stepmom's Desire   2020-05-29  movie     78.0           1.0
# 1        Pizza Dare 1   2020-04-10  movie     68.0           1.0
# 2          Bosomy Mom   2020-05-06  movie     69.0           1.0
# 3  Sonic the Hedgehog   2020-02-12  movie     99.0           1.0
# 4                  12   2020-09-04  movie     15.0           1.0
#
#    episode_count                                    genre       director  \
# 0            1.0                           Drama, Romance  Lee Dong-Joon
# 1            1.0                                  Romance   Kong Ja-kwan
# 2            1.0                           Drama, Romance  Lee Dong-Joon
# 3            1.0  Action, Science Fiction, Comedy, Family    Jeff Fowler
# 4            1.0                                      NaN  Salih Hashwan
#
#                                                 cast country language  \
# 0                   Lee Soo, Tae Hee, James, Jung In      KR       ko
# 1  Yoo Jung, Yoon So-jung, Jin Si-ah, Baek Yoon-j...      KR       ko
# 2        Yoo Jung, Han Yi-seul, James, Shin Yeon-woo      KR       ko
# 3  Ben Schwartz, James Marsden, Tika Sumpter, Jim...      US       en
# 4                                                NaN      SA       ar
#
#                                   production_company  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Original Film, Blur Studio, Marza Animation Pl...
# 4                                                NaN
#
#                                             synopsis  \
# 0  Sang-jin, who was envious of her neighbor afte...
# 1  Seok, who wants to try perverted sex, pesters ...
# 2  Da-hee gets married to Min-soo who is older th...
# 3  Powered with incredible speed, Sonic The Hedge...
# 4                                      not there yet
#
#                                                 tags  imdb_rating  \
# 0                                           softcore        7.150
# 1                                           softcore        6.222
# 2                                           softcore        5.900
# 3  friendship, video game, san francisco, califor...        7.307
# 4                                                NaN        5.481
#
#    imdb_review_count
# 0                 20
# 1                  9
# 2                 11
# 3               9955
# 4                 53

# %%
df_2020[(df_2020['type'] == 'tv') & (df_2020['season_count'].isna() | df_2020['episode_count'].isna())]
#df_2020[(df_2020['type'] == 'movie') & (df_2020['season_count'].isna() | df_2020['episode_count'].isna())]
# Out:
#                            title release_date type  runtime  season_count  \
# 12112                   The Wall   2020-01-01   tv      NaN           1.0
# 15026  واكلينها والعة: سبع صنايع   2020-07-08   tv      NaN           1.0
#
#        episode_count           genre              director  \
# 12112            NaN  War & Politics  Michael Krummenacher
# 15026            NaN             NaN                   NaN
#
#                                                     cast country language  \
# 12112  Barbara Auer, Thomas Thieme, Nadja Uhl, Alexan...      DE       de
# 15026  Sherif Ramzy, Mai Selim, Engy Wegdan, Yasser E...     NaN       ar
#
#       production_company synopsis tags  imdb_rating  imdb_review_count
# 12112                NaN      NaN  NaN          0.0                  0
# 15026                NaN      NaN  NaN          0.0                  0

# %%
print(df_2020_1[df_2020_1['season_count'] == 1.0]['episode_count'].value_counts(dropna=False))
# Out:
# episode_count
# 1.0      11828
# 6.0        702
# 8.0        569
# 4.0        530
# 10.0       504
#          ...
# 86.0         1
# 146.0        1
# 168.0        1
# 199.0        1
# 55.0         1
# Name: count, Length: 153, dtype: int64

# %%
print(df_2020_1[df_2020_1['episode_count'] == 1.0]['season_count'].value_counts(dropna=False))
# Out:
# season_count
# 1.0     11828
# 2.0        29
# 3.0         7
# 5.0         6
# 4.0         4
# 6.0         2
# 8.0         1
# 10.0        1
# 11.0        1
# Name: count, dtype: int64

# %%
df_2020_2 = df_2020_1
df_2020_2.loc[df_2020_2['type'] == 'tv', ['season_count', 'episode_count']] = df_2020_2.loc[df_2020_1['type'] == 'tv', ['season_count', 'episode_count']].fillna(1)
pd.set_option('display.max_columns', None)
df_2020_2.head()
# Out:
#                 title release_date   type  runtime  season_count  \
# 0    Stepmom's Desire   2020-05-29  movie     78.0           1.0
# 1        Pizza Dare 1   2020-04-10  movie     68.0           1.0
# 2          Bosomy Mom   2020-05-06  movie     69.0           1.0
# 3  Sonic the Hedgehog   2020-02-12  movie     99.0           1.0
# 4                  12   2020-09-04  movie     15.0           1.0
#
#    episode_count                                    genre       director  \
# 0            1.0                           Drama, Romance  Lee Dong-Joon
# 1            1.0                                  Romance   Kong Ja-kwan
# 2            1.0                           Drama, Romance  Lee Dong-Joon
# 3            1.0  Action, Science Fiction, Comedy, Family    Jeff Fowler
# 4            1.0                                      NaN  Salih Hashwan
#
#                                                 cast country language  \
# 0                   Lee Soo, Tae Hee, James, Jung In      KR       ko
# 1  Yoo Jung, Yoon So-jung, Jin Si-ah, Baek Yoon-j...      KR       ko
# 2        Yoo Jung, Han Yi-seul, James, Shin Yeon-woo      KR       ko
# 3  Ben Schwartz, James Marsden, Tika Sumpter, Jim...      US       en
# 4                                                NaN      SA       ar
#
#                                   production_company  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Original Film, Blur Studio, Marza Animation Pl...
# 4                                                NaN
#
#                                             synopsis  \
# 0  Sang-jin, who was envious of her neighbor afte...
# 1  Seok, who wants to try perverted sex, pesters ...
# 2  Da-hee gets married to Min-soo who is older th...
# 3  Powered with incredible speed, Sonic The Hedge...
# 4                                      not there yet
#
#                                                 tags  imdb_rating  \
# 0                                           softcore        7.150
# 1                                           softcore        6.222
# 2                                           softcore        5.900
# 3  friendship, video game, san francisco, califor...        7.307
# 4                                                NaN        5.481
#
#    imdb_review_count
# 0                 20
# 1                  9
# 2                 11
# 3               9955
# 4                 53

# %% [markdown]
# # 2. 데이터 전처리_runtime

# %%
df_2020_2.isnull().sum()
# Out:
# title                     0
# release_date              0
# type                      0
# runtime                5900
# season_count              0
# episode_count             0
# genre                  3871
# director               7949
# cast                   4456
# country                1665
# language                  0
# production_company     9140
# synopsis               4656
# tags                  15174
# imdb_rating               0
# imdb_review_count         0
# dtype: int64

# %%
df_2020_2.shape
# Out:
# (19628, 16)

# %%
df_2020_2[df_2020_2['runtime'].isna() & df_2020_2['genre'].isna() ].shape
# Out:
# (2640, 16)

# %% [markdown]
# ## 2_2 runtime null 값 열 제거

# %%
df_2020_3 = df_2020_2

# %%
df_2020_3.dropna(subset=['runtime'], inplace=True)

# %%
df_2020_3.shape
# Out:
# (13728, 16)

# %% [markdown]
# # 2. 데이터 전처리_pr

# %%
df_2020_4 = df_2020_3
df_2020_4
# Out:
#                        title release_date   type  runtime  season_count  \
# 0           Stepmom's Desire   2020-05-29  movie     78.0           1.0
# 1               Pizza Dare 1   2020-04-10  movie     68.0           1.0
# 2                 Bosomy Mom   2020-05-06  movie     69.0           1.0
# 3         Sonic the Hedgehog   2020-02-12  movie     99.0           1.0
# 4                         12   2020-09-04  movie     15.0           1.0
# ...                      ...          ...    ...      ...           ...
# 19567        L'art du voyage   2020-05-20     tv     51.0           1.0
# 19575                  神秘阿拉伯   2020-06-18     tv     51.0           1.0
# 19577        Polska Molskiej   2020-05-04     tv     21.0           1.0
# 19586                   雪耀中国   2020-11-22     tv     25.0           1.0
# 19592  I lære som sugardater   2020-10-17     tv     10.0           1.0
#
#        episode_count                                    genre       director  \
# 0                1.0                           Drama, Romance  Lee Dong-Joon
# 1                1.0                                  Romance   Kong Ja-kwan
# 2                1.0                           Drama, Romance  Lee Dong-Joon
# 3                1.0  Action, Science Fiction, Comedy, Family    Jeff Fowler
# 4                1.0                                      NaN  Salih Hashwan
# ...              ...                                      ...            ...
# 19567            1.0                              Documentary            NaN
# 19575            5.0                              Documentary            NaN
# 19577            6.0                              Documentary            NaN
# 19586            6.0                              Documentary            NaN
# 19592            1.0                                      NaN            NaN
#
#                                                     cast country language  \
# 0                       Lee Soo, Tae Hee, James, Jung In      KR       ko
# 1      Yoo Jung, Yoon So-jung, Jin Si-ah, Baek Yoon-j...      KR       ko
# 2            Yoo Jung, Han Yi-seul, James, Shin Yeon-woo      KR       ko
# 3      Ben Schwartz, James Marsden, Tika Sumpter, Jim...      US       en
# 4                                                    NaN      SA       ar
# ...                                                  ...     ...      ...
# 19567                                                NaN     NaN       fr
# 19575                                                NaN     NaN       zh
# 19577                                                NaN     NaN       pl
# 19586                                                NaN     NaN       zh
# 19592                                                NaN     NaN       da
#
#                                       production_company  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Original Film, Blur Studio, Marza Animation Pl...
# 4                                                    NaN
# ...                                                  ...
# 19567                                                NaN
# 19575                                                NaN
# 19577                                                NaN
# 19586                                                NaN
# 19592                                                NaN
#
#                                                 synopsis  \
# 0      Sang-jin, who was envious of her neighbor afte...
# 1      Seok, who wants to try perverted sex, pesters ...
# 2      Da-hee gets married to Min-soo who is older th...
# 3      Powered with incredible speed, Sonic The Hedge...
# 4                                          not there yet
# ...                                                  ...
# 19567                                                NaN
# 19575                                                NaN
# 19577                                                NaN
# 19586                                                NaN
# 19592                                                NaN
#
#                                                     tags  imdb_rating  \
# 0                                               softcore        7.150
# 1                                               softcore        6.222
# 2                                               softcore        5.900
# 3      friendship, video game, san francisco, califor...        7.307
# 4                                                    NaN        5.481
# ...                                                  ...          ...
# 19567                                                NaN        0.000
# 19575                                                NaN        0.000
# 19577                                                NaN        0.000
# 19586                                                NaN        0.000
# 19592                                                NaN        0.000
#
#        imdb_review_count
# 0                     20
# 1                      9
# 2                     11
# 3                   9955
# 4                     53
# ...                  ...
# 19567                  0
# 19575                  0
# 19577                  0
# 19586                  0
# 19592                  0
#
# [13728 rows x 16 columns]

# %%
df_2020_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13728 entries, 0 to 19592
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               13728 non-null  object
#  1   release_date        13728 non-null  object
#  2   type                13728 non-null  object
#  3   runtime             13728 non-null  float64
#  4   season_count        13728 non-null  float64
#  5   episode_count       13728 non-null  float64
#  6   genre               12497 non-null  object
#  7   director            10321 non-null  object
#  8   cast                12204 non-null  object
#  9   country             13274 non-null  object
#  10  language            13728 non-null  object
#  11  production_company  8658 non-null   object
#  12  synopsis            12040 non-null  object
#  13  tags                4226 non-null   object
#  14  imdb_rating         13728 non-null  float64
#  15  imdb_review_count   13728 non-null  int64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 1.8+ MB

# %% [markdown]
# ### tags 관련 기본 문제 해결

# %% [markdown]
# 1) synopsis, tags, genre가 모두 NaN인 데이터 모두 제거

# %%
# 1. 세기: synopsis, genre가 모두 NaN인 행 개수
nan_rows = df_2020_4[['synopsis', 'genre']].isna().all(axis=1)
count_nan_rows = nan_rows.sum()
print(f"synopsis, genre가 모두 NaN인 행 개수: {count_nan_rows}")
# Out:
# synopsis, genre가 모두 NaN인 행 개수: 442

# %%
# 2. 삭제: 그런 행 삭제
df_2020_4_cleaned = df_2020_4.loc[~nan_rows].copy()

# %%
df_2020_4 = df_2020_4.loc[~nan_rows].copy()
df_2020_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13286 entries, 0 to 19586
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               13286 non-null  object
#  1   release_date        13286 non-null  object
#  2   type                13286 non-null  object
#  3   runtime             13286 non-null  float64
#  4   season_count        13286 non-null  float64
#  5   episode_count       13286 non-null  float64
#  6   genre               12497 non-null  object
#  7   director            10089 non-null  object
#  8   cast                11903 non-null  object
#  9   country             13046 non-null  object
#  10  language            13286 non-null  object
#  11  production_company  8581 non-null   object
#  12  synopsis            12040 non-null  object
#  13  tags                4222 non-null   object
#  14  imdb_rating         13286 non-null  float64
#  15  imdb_review_count   13286 non-null  int64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 1.7+ MB

# %%
df_2020_4
# Out:
#                     title release_date   type  runtime  season_count  \
# 0        Stepmom's Desire   2020-05-29  movie     78.0           1.0
# 1            Pizza Dare 1   2020-04-10  movie     68.0           1.0
# 2              Bosomy Mom   2020-05-06  movie     69.0           1.0
# 3      Sonic the Hedgehog   2020-02-12  movie     99.0           1.0
# 4                      12   2020-09-04  movie     15.0           1.0
# ...                   ...          ...    ...      ...           ...
# 19539               错有持花梦   2020-11-27     tv      3.0           1.0
# 19567     L'art du voyage   2020-05-20     tv     51.0           1.0
# 19575               神秘阿拉伯   2020-06-18     tv     51.0           1.0
# 19577     Polska Molskiej   2020-05-04     tv     21.0           1.0
# 19586                雪耀中国   2020-11-22     tv     25.0           1.0
#
#        episode_count                                    genre       director  \
# 0                1.0                           Drama, Romance  Lee Dong-Joon
# 1                1.0                                  Romance   Kong Ja-kwan
# 2                1.0                           Drama, Romance  Lee Dong-Joon
# 3                1.0  Action, Science Fiction, Comedy, Family    Jeff Fowler
# 4                1.0                                      NaN  Salih Hashwan
# ...              ...                                      ...            ...
# 19539           13.0                                    Drama            NaN
# 19567            1.0                              Documentary            NaN
# 19575            5.0                              Documentary            NaN
# 19577            6.0                              Documentary            NaN
# 19586            6.0                              Documentary            NaN
#
#                                                     cast country language  \
# 0                       Lee Soo, Tae Hee, James, Jung In      KR       ko
# 1      Yoo Jung, Yoon So-jung, Jin Si-ah, Baek Yoon-j...      KR       ko
# 2            Yoo Jung, Han Yi-seul, James, Shin Yeon-woo      KR       ko
# 3      Ben Schwartz, James Marsden, Tika Sumpter, Jim...      US       en
# 4                                                    NaN      SA       ar
# ...                                                  ...     ...      ...
# 19539                                                NaN      CN       zh
# 19567                                                NaN     NaN       fr
# 19575                                                NaN     NaN       zh
# 19577                                                NaN     NaN       pl
# 19586                                                NaN     NaN       zh
#
#                                       production_company  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Original Film, Blur Studio, Marza Animation Pl...
# 4                                                    NaN
# ...                                                  ...
# 19539                                                NaN
# 19567                                                NaN
# 19575                                                NaN
# 19577                                                NaN
# 19586                                                NaN
#
#                                                 synopsis  \
# 0      Sang-jin, who was envious of her neighbor afte...
# 1      Seok, who wants to try perverted sex, pesters ...
# 2      Da-hee gets married to Min-soo who is older th...
# 3      Powered with incredible speed, Sonic The Hedge...
# 4                                          not there yet
# ...                                                  ...
# 19539                                                NaN
# 19567                                                NaN
# 19575                                                NaN
# 19577                                                NaN
# 19586                                                NaN
#
#                                                     tags  imdb_rating  \
# 0                                               softcore        7.150
# 1                                               softcore        6.222
# 2                                               softcore        5.900
# 3      friendship, video game, san francisco, califor...        7.307
# 4                                                    NaN        5.481
# ...                                                  ...          ...
# 19539                                                NaN        0.000
# 19567                                                NaN        0.000
# 19575                                                NaN        0.000
# 19577                                                NaN        0.000
# 19586                                                NaN        0.000
#
#        imdb_review_count
# 0                     20
# 1                      9
# 2                     11
# 3                   9955
# 4                     53
# ...                  ...
# 19539                  0
# 19567                  0
# 19575                  0
# 19577                  0
# 19586                  0
#
# [13286 rows x 16 columns]

# %% [markdown]
# ## director와 cast가 모두 nan인 행 제거

# %%
nan_both = df_2020_4[(df_2020_4['director'].isna()) & (df_2020_4['cast'].isna())]
print(f"director와 cast 둘 다 NaN인 행 개수: {len(nan_both)}")
# Out:
# director와 cast 둘 다 NaN인 행 개수: 778

# %%
df_2020_4 = df_2020_4.dropna(subset=['director', 'cast'], how='all')

# %%
df_2020_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12508 entries, 0 to 19331
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               12508 non-null  object
#  1   release_date        12508 non-null  object
#  2   type                12508 non-null  object
#  3   runtime             12508 non-null  float64
#  4   season_count        12508 non-null  float64
#  5   episode_count       12508 non-null  float64
#  6   genre               11795 non-null  object
#  7   director            10089 non-null  object
#  8   cast                11903 non-null  object
#  9   country             12365 non-null  object
#  10  language            12508 non-null  object
#  11  production_company  8200 non-null   object
#  12  synopsis            11563 non-null  object
#  13  tags                4211 non-null   object
#  14  imdb_rating         12508 non-null  float64
#  15  imdb_review_count   12508 non-null  int64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 1.6+ MB

# %% [markdown]
# # tag npl처리

# %%
# 1. tags 결측치는 빈 문자열로 대체
df_2020_4['tags'] = df_2020_4['tags'].fillna('')

# 2. synopsis, genre 결측치 처리 후 text_input 생성
df_2020_4['synopsis'] = df_2020_4['synopsis'].fillna('')
df_2020_4['genre'] = df_2020_4['genre'].fillna('')
df_2020_4['text_input'] = df_2020_4['synopsis'] + ' ' + df_2020_4['genre']

# 3. tags 기준으로 train / test 나누기
train_df = df_2020_4[df_2020_4['tags'] != ''].copy()
test_df = df_2020_4[df_2020_4['tags'] == ''].copy()

# 4. tags 리스트로 분리
train_df['tags_list'] = train_df['tags'].apply(lambda x: x.split(','))

# 5. 다중 라벨 인코딩
mlb = MultiLabelBinarizer()
y_train = mlb.fit_transform(train_df['tags_list'])

# 6. 텍스트 벡터화 (TF-IDF)
vectorizer = TfidfVectorizer(max_features=5000)
X_train = vectorizer.fit_transform(train_df['text_input'])

# 7. 모델 학습 (LogisticRegression 다중 라벨)
model = OneVsRestClassifier(LogisticRegression(max_iter=1000))
model.fit(X_train, y_train)

# 8. 예측 대상(test_df)이 비어있지 않으면 예측 수행
if not test_df.empty:
    X_test = vectorizer.transform(test_df['text_input'])
    y_prob = model.predict_proba(X_test)

    # 예측 임계값 설정 (낮춰서 태그 생성 늘림)
    threshold = 0.07
    y_pred = (y_prob >= threshold).astype(int)

    predicted_tags = mlb.inverse_transform(y_pred)
    test_df['predicted_tags'] = [', '.join(tags) if tags else np.nan for tags in predicted_tags]

    # 9. 규칙 기반 태그 보완용 키워드 룰 정의
    rules = {
        'romance': ['romance', 'love', 'relationship', 'affair', 'heart', 'kiss', 'wedding',
                    'boyfriend', 'girlfriend', 'breakup', 'dating', 'first love',
                    'valentine', 'romantic', 'jealousy', 'intimacy', 'honeymoon'],
        'action': ['battle', 'war', 'fight', 'soldier', 'gun', 'explosion', 'chase', 'enemy',
                'car chase', 'explosives', 'gunfight', 'hand-to-hand', 'sniper',
                'ambush', 'mercenary', 'adrenaline', 'combat', 'high-octane'],
        'thriller': ['thriller', 'mystery', 'suspense', 'crime', 'killer', 'murder', 'detective',
                    'interrogation', 'conspiracy', 'mind game', 'tension', 'abduction',
                    'dangerous', 'mind-bending', 'ticking clock', 'trap'],
        'comedy': ['comedy', 'funny', 'humor', 'laugh', 'joke', 'parody',
                'sitcom', 'sarcasm', 'one-liner', 'slapstick', 'banter',
                'awkward moment', 'gag', 'prank', 'hilarity'],
        'horror': ['ghost', 'horror', 'zombie', 'demon', 'vampire', 'curse',
                'haunted', 'scream', 'paranormal', 'supernatural', 'bloodcurdling',
                'creepy', 'terrifying', 'evil spirit', 'possessed', 'ritual'],
        'fantasy': ['magic', 'wizard', 'dragon', 'kingdom', 'mythical',
                    'sorcerer', 'enchanted', 'portal', 'spell', 'epic quest',
                    'mystical creature', 'ancient prophecy', 'grimoire'],
        'sci-fi': ['space', 'alien', 'robot', 'future', 'technology', 'sci-fi', 'cyber',
                'cyborg', 'AI uprising', 'time machine', 'spaceship', 'hyperspace',
                'galaxy', 'terraforming', 'futuristic', 'parallel universe', 'bioengineering'],
        'drama': ['family', 'life', 'struggle', 'emotional', 'drama', 'society',
                'inner struggle', 'self-discovery', 'character driven', 'emotional arc',
                'breakdown', 'life lesson', 'interpersonal', 'catharsis'],
        'crime': ['criminal', 'robbery', 'heist', 'mafia', 'gang',
                'heist', 'detective', 'undercover', 'criminal syndicate',
                'drug cartel', 'interrogation room', 'forensics', 'manhunt'],
        'animation': ['animation', 'cartoon', 'drawn', 'animated'],
        'sports': ['sports', 'football', 'basketball', 'coach', 'tournament'],
        'historical': ['king', 'queen', 'dynasty', 'empire', 'history', 'ancient'],
        'adventure': ['journey', 'quest', 'treasure', 'explore', 'island', 'survival'],
        'musical': ['song', 'singing', 'performance', 'dance', 'stage', 'music'],
        'documentary': ['real', 'true story', 'interview', 'archive', 'biography', 'footage'],
        'psychological': ['mind', 'mental', 'insanity', 'delusion', 'subconscious', 'dream'],
        'superhero': ['hero', 'superpower', 'villain', 'save', 'city', 'mask'],
        'noir': ['detective', 'dark', 'cigarette', 'femme fatale', 'shadow', 'monologue'],
        'family': ['parent', 'child', 'home', 'holiday', 'siblings', 'bond'],
        'rom-com': ['love', 'funny', 'awkward', 'date', 'charm', 'happy ending'],
        'military': ['army', 'navy', 'mission', 'rank', 'base', 'operation'],
        'cyberpunk': ['neon', 'hacker', 'corporation', 'dystopia', 'implant', 'surveillance'],
        'post-apocalyptic': ['ruins', 'survivor', 'radiation', 'collapse', 'tribe', 'scavenge'],
        'teen': ['high school', 'prom', 'friendship', 'coming of age', 'crush', 'rebellion'],
        'feel-good': ['inspiring', 'heartwarming', 'uplifting', 'positive', 'hope', 'smile'],
        'dark': ['depressing', 'grim', 'tragic', 'bleak', 'morbid'],
        'female-lead': ['strong woman', 'heroine', 'female protagonist', 'girl power'],
        'twist': ['plot twist', 'unpredictable', 'reveal', 'surprise ending'],
        'based-on-true-story': ['true story', 'biopic', 'real events', 'true events'],
        'underdog': ['struggle', 'rise', 'overcome', 'unlikely hero', 'against all odds'],
        'ensemble': ['many characters', 'multiple leads', 'group dynamic', 'interwoven stories'],
        'nostalgic': ['retro', 'classic', 'throwback', '80s', '90s', 'childhood'],
        'social-issue': ['racism', 'inequality', 'poverty', 'justice', 'activism'],
        'trending-theme': ['AI', 'climate', 'pandemic', 'influencer', 'metaverse'],
        'revenge': ['revenge', 'vengeance', 'payback', 'retaliation', 'score to settle'],
        'detective': ['detective', 'investigation', 'clues', 'case', 'inspector', 'sleuth'],
        'time-travel': ['time travel', 'time loop', 'past and future', 'timeline', 'chronosphere'],
        'courtroom': ['courtroom', 'trial', 'lawyer', 'judge', 'defendant', 'testimony'],
        'survival': ['survival', 'wilderness', 'isolation', 'extreme conditions', 'barely escape'],
        'espionage': ['spy', 'espionage', 'agent', 'undercover', 'intel', 'classified'],
        'campus': ['college', 'campus', 'lecture hall', 'seniors', 'dorm', 'professor'],
        'startup': ['startup', 'entrepreneur', 'founder', 'venture', 'pitching', 'angel investor'],
        'heist': ['heist', 'robbery', 'master plan', 'getaway', 'vault', 'crew'],
        'royalty': ['prince', 'princess', 'royal', 'crown', 'throne', 'palace'],
        'wuxia': ['martial arts', 'swordplay', 'wuxia', 'clan', 'sect', 'inner energy'],
        'idol': ['idol', 'stage', 'fandom', 'trainee', 'debut', 'fan meeting'],
        'political': ['election', 'politics', 'scandal', 'congress', 'corruption', 'regime'],
        'revenge-romance': ['bitter love', 'masked identity', 'burning passion', 'payback with love'],
        'healing-romance': ['gentle romance', 'emotional support', 'quiet relationship', 'warm affection'],
        'coming-of-age': ['self-discovery', 'growing up', 'teenage years', 'puberty',
                        'youth', 'maturity', 'identity', 'high school', 'first time', 'life lessons'],
        'dark-comedy': ['dark humor', 'macabre laugh', 'twisted joke', 'morbidly funny',
                        'ironic death', 'satirical tragedy', 'deadpan', 'black comedy'],
        'dystopian': ['oppressive regime', 'totalitarian', 'no freedom', 'surveillance state',
                    'rebellion', 'social collapse', 'harsh world', 'authoritarian', 'controlled society'],
        'slice-of-life': ['daily routine', 'ordinary moments', 'casual life', 'everyday drama',
                        'subtle emotion', 'mundane beauty', 'life as it is', 'quiet narrative'],
        'found-family': ['bond', 'unrelated family', 'loyal companions', 'chosen family',
                        'support system', 'teamwork', 'squad', 'surrogate parents', 'emotional ties'],
        'road-trip': ['on the road', 'journey across', 'miles', 'car travel', 'hit the road',
                    'cross-country', 'travel companions', 'gas station', 'stopover', 'long drive'],
        'tech-noir': ['grim future', 'tech-savvy criminal', 'neon-lit', 'cyber corruption',
                    'urban decay', 'AI rebellion', 'cyberspace', 'digital heist', 'surveillance overload'],
        'folklore': ['legend', 'traditional tale', 'mythical creature', 'ancient lore',
                    'cultural story', 'spirit', 'oral tradition', 'forest demon', 'village tale']
    }

    def simple_tag_rule(text):
        text = text.lower()
        tags = set()
        for tag, keywords in rules.items():
            if any(word in text for word in keywords):
                tags.add(tag)
        return ', '.join(tags) if tags else np.nan

    # 10. 예측 실패 (nan)인 경우 규칙 기반으로 태그 보완
    no_tag_idx = test_df[test_df['predicted_tags'].isna()].index
    test_df.loc[no_tag_idx, 'predicted_tags'] = test_df.loc[no_tag_idx, 'text_input'].apply(simple_tag_rule)

    # 11. 원본에 태그 삽입
    df_2020_4.loc[test_df.index, 'tags'] = test_df['predicted_tags']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\3016739564.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['tags'] = df_2020_4['tags'].fillna('')
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\3016739564.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['synopsis'] = df_2020_4['synopsis'].fillna('')
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\3016739564.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['genre'] = df_2020_4['genre'].fillna('')
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\3016739564.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['text_input'] = df_2020_4['synopsis'] + ' ' + df_2020_4['genre']

# %%
df_2020_4['tags'].value_counts(dropna=False)
# Out:
# tags
#  short film                                 1752
# softcore                                     704
#  short film, short film                      278
# stand-up comedy                              226
# short film                                   189
#                                             ...
# drama, action, historical, thriller            1
# crime, action, thriller                        1
# sheep, iceland, astronaut, lunar mission       1
# drama, horror, adventure, thriller             1
# military, road-trip, sci-fi, historical        1
# Name: count, Length: 6365, dtype: int64

# %% [markdown]
# # country에서 nan은 language와 같은 값으로 처리

# %%
df_2020_4.isnull().sum()
# Out:
# title                    0
# release_date             0
# type                     0
# runtime                  0
# season_count             0
# episode_count            0
# genre                    0
# director              2419
# cast                   605
# country                143
# language                 0
# production_company    4308
# synopsis                 0
# tags                   153
# imdb_rating              0
# imdb_review_count        0
# text_input               0
# dtype: int64

# %%
df_2020_4['country'].fillna(df_2020_4['language'], inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\3399969867.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_2020_4['country'].fillna(df_2020_4['language'], inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\3399969867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['country'].fillna(df_2020_4['language'], inplace=True)

# %%
df_2020_4.isnull().sum()
# Out:
# title                    0
# release_date             0
# type                     0
# runtime                  0
# season_count             0
# episode_count            0
# genre                    0
# director              2419
# cast                   605
# country                  0
# language                 0
# production_company    4308
# synopsis                 0
# tags                   153
# imdb_rating              0
# imdb_review_count        0
# text_input               0
# dtype: int64

# %%
df_2020_4['production_company'].value_counts(dropna=False)
# Out:
# production_company
# NaN                                                         4308
# TVB                                                           22
# DR TV                                                         20
# NHK                                                           18
# Česká televize                                                17
#                                                             ...
# Ziegler Film                                                   1
# Causeway Films                                                 1
# Gravitas Ventures, Transmission Pictures, Vague Pictures       1
# Sucheta Dreamworks Productions                                 1
# Jiangsu Qiangsheng culture media                               1
# Name: count, Length: 6998, dtype: int64

# %% [markdown]
# # production_company, director, cast _is_comming 처리
# - 결측 값이 많아 이렇게 진행
# - 정보 부족이지 하나의 회사명, 이름은 x
# - 'unknown'만 삽입했을 경우 정상 값이라고 학습하는 것을 방지 => unknown으로 채우되 값은 없음으로 지정하기 위해 사용

# %%
unique_count = df_2020_4['production_company'].nunique(dropna=True)
print(unique_count)
# Out:
# 6997

# %%
df_2020_4['production_company_is_missing'] = df_2020_4['production_company'].isna().astype(int)
df_2020_4['production_company'] = df_2020_4['production_company'].fillna('unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\1818592304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['production_company_is_missing'] = df_2020_4['production_company'].isna().astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\1818592304.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['production_company'] = df_2020_4['production_company'].fillna('unknown')

# %%
df_2020_4['cast_is_missing'] = df_2020_4['cast'].isna().astype(int)
df_2020_4['cast'] = df_2020_4['cast'].fillna('unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\438636211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['cast_is_missing'] = df_2020_4['cast'].isna().astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\438636211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['cast'] = df_2020_4['cast'].fillna('unknown')

# %%
df_2020_4['director_is_missing'] = df_2020_4['director'].isna().astype(int)
df_2020_4['director'] = df_2020_4['director'].fillna('unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\1633940532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['director_is_missing'] = df_2020_4['director'].isna().astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_32928\1633940532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_4['director'] = df_2020_4['director'].fillna('unknown')
#                        title release_date   type  runtime  season_count  \
# 0           Stepmom's Desire   2020-05-29  movie     78.0           1.0
# 1               Pizza Dare 1   2020-04-10  movie     68.0           1.0
# 2                 Bosomy Mom   2020-05-06  movie     69.0           1.0
# 3         Sonic the Hedgehog   2020-02-12  movie     99.0           1.0
# 4                         12   2020-09-04  movie     15.0           1.0
# ...                      ...          ...    ...      ...           ...
# 18810   De usårlige betjente   2020-08-17     tv     29.0           1.0
# 18912              行疆：尼泊尔ACT   2020-05-30     tv     20.0           1.0
# 18992  L'amérique inexplorée   2020-12-06     tv     52.0           1.0
# 19160                     藏家   2020-12-08     tv     25.0           1.0
# 19331                    么么侠   2020-01-01     tv     14.0           1.0
#
#        episode_count                                    genre  \
# 0                1.0                           Drama, Romance
# 1                1.0                                  Romance
# 2                1.0                           Drama, Romance
# 3                1.0  Action, Science Fiction, Comedy, Family
# 4                1.0
# ...              ...                                      ...
# 18810            4.0                              Documentary
# 18912            1.0                              Documentary
# 18992            1.0                              Documentary
# 19160            6.0                              Documentary
# 19331           13.0                                Animation
#
#               director                                               cast  \
# 0        Lee Dong-Joon                   Lee Soo, Tae Hee, James, Jung In
# 1         Kong Ja-kwan  Yoo Jung, Yoon So-jung, Jin Si-ah, Baek Yoon-j...
# 2        Lee Dong-Joon        Yoo Jung, Han Yi-seul, James, Shin Yeon-woo
# 3          Jeff Fowler  Ben Schwartz, James Marsden, Tika Sumpter, Jim...
# 4        Salih Hashwan                                                NaN
# ...                ...                                                ...
# 18810          unknown                                      Michael Molin
# 18912          unknown                                                 况露
# 18992  Mathieu Despiau                                                NaN
# 19160          unknown                                          Che Ailin
# 19331    Xiaoqiang Guo                                                NaN
#
#       country language                                 production_company  \
# 0          KR       ko                                            unknown
# 1          KR       ko                                            unknown
# 2          KR       ko                                            unknown
# 3          US       en  Original Film, Blur Studio, Marza Animation Pl...
# 4          SA       ar                                            unknown
# ...       ...      ...                                                ...
# 18810      DK       da                                              DR TV
# 18912      CN       zh                                            unknown
# 18992      fr       fr                                            unknown
# 19160      CN       zh                                               CCTV
# 19331      CN       zh                   Jiangsu Qiangsheng culture media
#
#                                                 synopsis  \
# 0      Sang-jin, who was envious of her neighbor afte...
# 1      Seok, who wants to try perverted sex, pesters ...
# 2      Da-hee gets married to Min-soo who is older th...
# 3      Powered with incredible speed, Sonic The Hedge...
# 4                                          not there yet
# ...                                                  ...
# 18810
# 18912
# 18992
# 19160
# 19331
#
#                                                     tags  imdb_rating  \
# 0                                               softcore        7.150
# 1                                               softcore        6.222
# 2                                               softcore        5.900
# 3      friendship, video game, san francisco, califor...        7.307
# 4                                 short film, short film        5.481
# ...                                                  ...          ...
# 18810                                          biography        0.000
# 18912                                          biography        8.000
# 18992                                          biography        0.000
# 19160                                          biography        0.000
# 19331                     anime,  short film, short film        0.000
#
#        imdb_review_count                                         text_input  \
# 0                     20  Sang-jin, who was envious of her neighbor afte...
# 1                      9  Seok, who wants to try perverted sex, pesters ...
# 2                     11  Da-hee gets married to Min-soo who is older th...
# 3                   9955  Powered with incredible speed, Sonic The Hedge...
# 4                     53                                     not there yet
# ...                  ...                                                ...
# 18810                  0                                        Documentary
# 18912                  1                                        Documentary
# 18992                  0                                        Documentary
# 19160                  0                                        Documentary
# 19331                  0                                          Animation
#
#        production_company_is_missing  director_is_missing
# 0                                  1                    0
# 1                                  1                    0
# 2                                  1                    0
# 3                                  0                    0
# 4                                  1                    0
# ...                              ...                  ...
# 18810                              0                    1
# 18912                              1                    1
# 18992                              1                    0
# 19160                              0                    1
# 19331                              0                    0
#
# [12508 rows x 19 columns]

# %%
print(df_2020_4.shape)
print(df_2020_4.isnull().sum())
# Out:
# (12508, 20)
# title                              0
# release_date                       0
# type                               0
# runtime                            0
# season_count                       0
# episode_count                      0
# genre                              0
# director                           0
# cast                               0
# country                            0
# language                           0
# production_company                 0
# synopsis                           0
# tags                             153
# imdb_rating                        0
# imdb_review_count                  0
# text_input                         0
# production_company_is_missing      0
# director_is_missing                0
# cast_is_missing                    0
# dtype: int64

# %%
nan_tags_rows = df_2020_4[df_2020_4['tags'].isna()]
nan_tags_rows
# Out:
#                                                    title release_date   type  \
# 1145                                        Unprescribed   2020-02-22  movie
# 1314              Stuntwomen: The Untold Hollywood Story   2020-09-22  movie
# 1775                   Frontline: America's Great Divide   2020-01-13  movie
# 1908                                           Dérapages   2020-11-16  movie
# 2228   Memories of Monroeville: Revisiting the 'Dawn ...   2020-11-16  movie
# ...                                                  ...          ...    ...
# 16185              Retrospective 2020: Globoplay Edition   2020-12-29     tv
# 16970                                     All The Things   2020-11-09     tv
# 17180                           The Signature of Flowers   2020-05-01     tv
# 17209                                  Jonahs dyreverden   2020-02-15     tv
# 17651                The School That Tried To End Racism   2020-06-25     tv
#
#        runtime  season_count  episode_count              genre  \
# 1145      71.0           1.0            1.0        Documentary
# 1314      84.0           1.0            1.0        Documentary
# 1775     228.0           1.0            1.0        Documentary
# 1908       3.0           1.0            1.0        Documentary
# 2228      34.0           1.0            1.0        Documentary
# ...        ...           ...            ...                ...
# 16185     40.0           1.0            5.0  Documentary, News
# 16970     18.0           1.0            6.0        Documentary
# 17180     45.0           1.0            5.0        Documentary
# 17209     10.0           2.0           20.0  Kids, Documentary
# 17651     47.0           1.0            2.0        Documentary
#
#                          director  \
# 1145                Steve Ellmore
# 1314                 April Wright
# 1775                 Michael Kirk
# 1908               Gérard Courant
# 2228                David Gregory
# ...                           ...
# 16185                Silvia Sayão
# 16970               Amanda Duggan
# 17180               Yinghao Huang
# 17209                     unknown
# 17651  Rachel Dupuy, David Harris
#
#                                                     cast country language  \
# 1145                                             unknown      US       en
# 1314   Michelle Rodriguez, Ben Mankiewicz, Paul Verho...      US       en
# 1775   David Axelrod, Wesley Lowery, Megyn Kelly, Ben...      US       en
# 1908                                             unknown      FR       fr
# 2228   Taso N. Stavrakis, Tom Savini, Tom Dubensky, M...      US       en
# ...                                                  ...     ...      ...
# 16185                     Sandra Annenberg, Glória Maria      BR       pt
# 16970                                     Cherie Hausler      AU       en
# 17180                                            unknown      CN       zh
# 17209                Remi Andersen, Jonah Stene Andersen      NO       no
# 17651                                            unknown      GB       en
#
#                                       production_company  \
# 1145                                             unknown
# 1314   Gruskoff Films, Neasden Productions, Beachwood...
# 1775                                                 GBH
# 1908   Les Amis de Cinématon, Les Archives de l’Art C...
# 2228                                       Severin Films
# ...                                                  ...
# 16185                                            unknown
# 16970                               TAV Productions (AU)
# 17180                                            unknown
# 17209                                                NRK
# 17651                                        Proper Film
#
#                                                 synopsis tags  imdb_rating  \
# 1145   Amid the opioid and suicide epidemics, militar...  NaN          0.0
# 1314   Chronicles the lives of women who perform the ...  NaN          6.2
# 1775   A deep look into the growing divide in America...  NaN          8.2
# 1908   During a shoot with an Eagle K4 camera, a fail...  NaN          0.0
# 2228   A tour of 'Dawn of the Dead's Monroeville mall...  NaN          7.0
# ...                                                  ...  ...          ...
# 16185                                                     NaN          5.0
# 16970  An exploration of an endless array of farm pro...  NaN          0.0
# 17180  The five-episode Chinese documentary series re...  NaN          0.0
# 17209                                                     NaN          1.0
# 17651  Documentary about a pioneering British school ...  NaN          9.0
#
#        imdb_review_count                                         text_input  \
# 1145                   0  Amid the opioid and suicide epidemics, militar...
# 1314                   9  Chronicles the lives of women who perform the ...
# 1775                   5  A deep look into the growing divide in America...
# 1908                   0  During a shoot with an Eagle K4 camera, a fail...
# 2228                   1  A tour of 'Dawn of the Dead's Monroeville mall...
# ...                  ...                                                ...
# 16185                  1                                  Documentary, News
# 16970                  0  An exploration of an endless array of farm pro...
# 17180                  0  The five-episode Chinese documentary series re...
# 17209                  1                                  Kids, Documentary
# 17651                  2  Documentary about a pioneering British school ...
#
#        production_company_is_missing  director_is_missing  cast_is_missing
# 1145                               1                    0                1
# 1314                               0                    0                0
# 1775                               0                    0                0
# 1908                               0                    0                1
# 2228                               0                    0                0
# ...                              ...                  ...              ...
# 16185                              1                    0                0
# 16970                              0                    0                0
# 17180                              1                    0                1
# 17209                              0                    1                0
# 17651                              0                    0                1
#
# [153 rows x 20 columns]

# %%
df_2020_5 = df_2020_4[df_2020_4['tags'].notna()].copy()
df_2020_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12355 entries, 0 to 19331
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   title                          12355 non-null  object
#  1   release_date                   12355 non-null  object
#  2   type                           12355 non-null  object
#  3   runtime                        12355 non-null  float64
#  4   season_count                   12355 non-null  float64
#  5   episode_count                  12355 non-null  float64
#  6   genre                          12355 non-null  object
#  7   director                       12355 non-null  object
#  8   cast                           12355 non-null  object
#  9   country                        12355 non-null  object
#  10  language                       12355 non-null  object
#  11  production_company             12355 non-null  object
#  12  synopsis                       12355 non-null  object
#  13  tags                           12355 non-null  object
#  14  imdb_rating                    12355 non-null  float64
#  15  imdb_review_count              12355 non-null  int64
#  16  text_input                     12355 non-null  object
#  17  production_company_is_missing  12355 non-null  int32
#  18  director_is_missing            12355 non-null  int32
#  19  cast_is_missing                12355 non-null  int32
# dtypes: float64(4), int32(3), int64(1), object(12)
# memory usage: 1.8+ MB

# %%
df_2020_5.to_csv('전처리_완료(csv)/2020년도 전처리.csv', index=False)
