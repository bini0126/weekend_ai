# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1. 데이터 준비 및 탐색

# %%
df= pd.read_csv("./cruise_ship_info.csv")
df.head()
# Out:
#      Ship_name Cruise_line  Age  Tonnage  passengers  length  cabins
# 0      Journey     Azamara    6   30.277        6.94    5.94    3.55  \
# 1        Quest     Azamara    6   30.277        6.94    5.94    3.55
# 2  Celebration    Carnival   26   47.262       14.86    7.22    7.43
# 3     Conquest    Carnival   11  110.000       29.74    9.53   14.88
# 4      Destiny    Carnival   17  101.353       26.42    8.92   13.21
#
#    passenger_density   crew
# 0              42.64   3.55
# 1              42.64   3.55
# 2              31.80   6.70
# 3              36.99  19.10
# 4              38.36  10.00

# %%
df.columns
# Out:
# Index(['Ship_name', 'Cruise_line', 'Age', 'Tonnage', 'passengers', 'length',
#        'cabins', 'passenger_density', 'crew'],
#       dtype='object')

# %% [markdown]
# - 피처
#     - ship_name : 선박 이름
#     - Cruise_line : 크루즈 라인
#     - Age : 2013년 기준 연령
#     - Tonnage : 선박의 용량을 나타내는 단위(1000s of tons)
#     - passengers : 승객 (100s)
#     - length : 길이 (100s of feet)
#     - cabins : 선실 (100s)
#     - passenger_desity : 승객 밀도
#     - crew : 승무원 (100s)

# %%
df.shape
# Out:
# (158, 9)

# %%
df.dtypes
# Out:
# Ship_name             object
# Cruise_line           object
# Age                    int64
# Tonnage              float64
# passengers           float64
# length               float64
# cabins               float64
# passenger_density    float64
# crew                 float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Ship_name            0
# Cruise_line          0
# Age                  0
# Tonnage              0
# passengers           0
# length               0
# cabins               0
# passenger_density    0
# crew                 0
# dtype: int64

# %%
df.describe()
# Out:
#               Age     Tonnage  passengers      length      cabins
# count  158.000000  158.000000  158.000000  158.000000  158.000000  \
# mean    15.689873   71.284671   18.457405    8.130633    8.830000
# std      7.615691   37.229540    9.677095    1.793474    4.471417
# min      4.000000    2.329000    0.660000    2.790000    0.330000
# 25%     10.000000   46.013000   12.535000    7.100000    6.132500
# 50%     14.000000   71.899000   19.500000    8.555000    9.570000
# 75%     20.000000   90.772500   24.845000    9.510000   10.885000
# max     48.000000  220.000000   54.000000   11.820000   27.000000
#
#        passenger_density        crew
# count         158.000000  158.000000
# mean           39.900949    7.794177
# std             8.639217    3.503487
# min            17.700000    0.590000
# 25%            34.570000    5.480000
# 50%            39.085000    8.150000
# 75%            44.185000    9.990000
# max            71.430000   21.000000

# %% [markdown]
# ### 2. 시각화

# %%
df_label = ["Age", "Tonnage", "passengers", "length", "cabins", "passenger_density", "crew"]

# %%
sns.pairplot(df[df_label], height=2.0)

# %%
df_heat = df.columns[2:]
df_heat
# Out:
# Index(['Age', 'Tonnage', 'passengers', 'length', 'cabins', 'passenger_density',
#        'crew'],
#       dtype='object')

# %%
df_heat = df[df_heat].corr()
df_heat
# Out:
#                         Age   Tonnage  passengers    length    cabins
# Age                1.000000 -0.606646   -0.515542 -0.532286 -0.510019  \
# Tonnage           -0.606646  1.000000    0.945061  0.922368  0.948764
# passengers        -0.515542  0.945061    1.000000  0.883535  0.976341
# length            -0.532286  0.922368    0.883535  1.000000  0.889798
# cabins            -0.510019  0.948764    0.976341  0.889798  1.000000
# passenger_density -0.278830 -0.040846   -0.294867 -0.090488 -0.253181
# crew              -0.530657  0.927569    0.915234  0.895857  0.950823
#
#                    passenger_density      crew
# Age                        -0.278830 -0.530657
# Tonnage                    -0.040846  0.927569
# passengers                 -0.294867  0.915234
# length                     -0.090488  0.895857
# cabins                     -0.253181  0.950823
# passenger_density           1.000000 -0.155509
# crew                       -0.155509  1.000000

# %%
df_label = ["Age", "Tonnage", "passengers", "length", "cabins", "passenger_density", "crew"]

sns.heatmap(df_heat.values, cbar = True, annot= True, fmt = ".3f",
            yticklabels= df_heat, xticklabels= df_heat)
plt.show()

# %% [markdown]
# - "Crew" 피처와 관련해...
#     - "Cabins" 피처와 가장 큰 관련성 가짐 ("cabins" > "Tonnage" > "passengers" > "length")
#     - "Age", "passenger_density" 피처와는 음수성을 나타내며 연관성이 없으므로 해당 피처 제거
#     - 또한 승무원 수를 구하는데에 "Ship_name"과 "Cruise_line"은 관련성이 없기 때문에 해당 피처 제거
#
#     =>따라서 "Crew"수를 예측하는데 필요한 데이터 : <strong>"cabins", "Tonnage", "passengers", "length", "crew" </strong>

# %%
ship_crew = df[[ "cabins", "Tonnage", "passengers", "length", "crew"]]
ship_crew.head()
# Out:
#    cabins  Tonnage  passengers  length   crew
# 0    3.55   30.277        6.94    5.94   3.55
# 1    3.55   30.277        6.94    5.94   3.55
# 2    7.43   47.262       14.86    7.22   6.70
# 3   14.88  110.000       29.74    9.53  19.10
# 4   13.21  101.353       26.42    8.92  10.00

# %% [markdown]
# ### 3. 회귀 돌리기

# %%
x = ship_crew.drop("crew", axis=1)
y = ship_crew["crew"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=22)

# %%
x_train.shape, x_test.shape
# Out:
# ((118, 4), (40, 4))

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 모델 평가
lr.score(x_test, y_test)
# Out:
# 0.9535426891482373

# %%
pred = lr.predict(x_test)

# %%
# mean_squared_error 평가
mse = mean_squared_error(y_test, pred)
mse
# Out:
# 0.6781564604579403

# %%
pred_df = pd.DataFrame({"ans" : y_test, "pred" : pred})
pred_df
# Out:
#        ans       pred
# 115   4.45   4.587584
# 77   11.09  10.549385
# 35    9.20   9.630282
# 46    5.45   5.463421
# 112   9.00   8.771927
# 141  11.76  13.584162
# 94    9.00   8.634762
# 31    9.99   9.208699
# 66    7.00   7.265477
# 30    6.70   5.976850
# 41    9.20   9.646815
# 13    9.20   8.811007
# 92    5.20   5.248449
# 10   11.60  12.396638
# 91    8.69   9.194425
# 120   8.48   8.957580
# 148   1.97   2.245014
# 2     6.70   6.535949
# 68    7.00   7.118831
# 86    6.14   7.370693
# 131  11.85  13.584162
# 122   7.60   8.846613
# 123  11.76  13.584162
# 134  21.00  21.768431
# 124  13.60  14.066217
# 39   10.68  11.437692
# 22   11.60  12.399188
# 25    9.99   9.208699
# 155   0.88   1.390975
# 43   10.90  10.988275
# 64    5.31   6.925173
# 104  11.10  11.410136
# 110   9.00   8.771927
# 119  11.85  13.584162
# 76    6.14   7.370693
# 149   0.59   0.744842
# 71    7.40   7.464032
# 54    5.57   6.150124
# 153   0.59   0.742291
# 20   10.29   9.693720

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df.head()
# Out:
#      Ship_name Cruise_line  Age  Tonnage  passengers  length  cabins
# 0      Journey     Azamara    6   30.277        6.94    5.94    3.55  \
# 1        Quest     Azamara    6   30.277        6.94    5.94    3.55
# 2  Celebration    Carnival   26   47.262       14.86    7.22    7.43
# 3     Conquest    Carnival   11  110.000       29.74    9.53   14.88
# 4      Destiny    Carnival   17  101.353       26.42    8.92   13.21
#
#    passenger_density   crew
# 0              42.64   3.55
# 1              42.64   3.55
# 2              31.80   6.70
# 3              36.99  19.10
# 4              38.36  10.00

# %%
df.columns
# Out:
# Index(['Ship_name', 'Cruise_line', 'Age', 'Tonnage', 'passengers', 'length',
#        'cabins', 'passenger_density', 'crew'],
#       dtype='object')

# %%
target = ["Age", "Tonnage", "passengers", "length", "cabins", "passenger_density", "crew"]

scaler = MinMaxScaler()
df2 = df.copy()
df2[target] = scaler.fit_transform(df2[target])
df2.head()
# Out:
#      Ship_name Cruise_line       Age   Tonnage  passengers    length
# 0      Journey     Azamara  0.045455  0.128396    0.117735  0.348837  \
# 1        Quest     Azamara  0.045455  0.128396    0.117735  0.348837
# 2  Celebration    Carnival  0.500000  0.206426    0.266217  0.490587
# 3     Conquest    Carnival  0.159091  0.494650    0.545182  0.746401
# 4      Destiny    Carnival  0.295455  0.454925    0.482940  0.678848
#
#      cabins  passenger_density      crew
# 0  0.120735           0.464173  0.145027
# 1  0.120735           0.464173  0.145027
# 2  0.266217           0.262423  0.299363
# 3  0.545557           0.359017  0.906908
# 4  0.482940           0.384515  0.461049

# %%
df2_corr = df2.iloc[1: , :].corr(numeric_only=True)
plt.figure(figsize=(20, 20))
sns.clustermap(df2_corr, annot = True, cmap = 'RdYlBu_r', vmin = -1, vmax = 1)

plt.show()

# %%
df2.head()
# Out:
#      Ship_name Cruise_line       Age   Tonnage  passengers    length
# 0      Journey     Azamara  0.045455  0.128396    0.117735  0.348837  \
# 1        Quest     Azamara  0.045455  0.128396    0.117735  0.348837
# 2  Celebration    Carnival  0.500000  0.206426    0.266217  0.490587
# 3     Conquest    Carnival  0.159091  0.494650    0.545182  0.746401
# 4      Destiny    Carnival  0.295455  0.454925    0.482940  0.678848
#
#      cabins  passenger_density      crew
# 0  0.120735           0.464173  0.145027
# 1  0.120735           0.464173  0.145027
# 2  0.266217           0.262423  0.299363
# 3  0.545557           0.359017  0.906908
# 4  0.482940           0.384515  0.461049

# %%
df2 = df2[["cabins", "Tonnage", "passengers", "length", "crew"]]
df2.head()
# Out:
#      cabins   Tonnage  passengers    length      crew
# 0  0.120735  0.128396    0.117735  0.348837  0.145027
# 1  0.120735  0.128396    0.117735  0.348837  0.145027
# 2  0.266217  0.206426    0.266217  0.490587  0.299363
# 3  0.545557  0.494650    0.545182  0.746401  0.906908
# 4  0.482940  0.454925    0.482940  0.678848  0.461049

# %%
x = df2.drop("crew", axis = 1)
y = df2["crew"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=22)

x_train.shape, x_test.shape
# Out:
# ((118, 4), (40, 4))

# %%
lr = LinearRegression()

lr.fit(x_train, y_train)
lr.score(x_test, y_test)
# Out:
# 0.9535426891482373

# %%
pred = lr.predict(x_test)

# %%
mse = mean_squared_error(y_test, pred)
mse
# Out:
# 0.0016279606154622525

# %%
pred_df = pd.DataFrame({"ans" : y_test, "pred" : pred})
pred_df
# Out:
#           ans      pred
# 115  0.189123  0.195864
# 77   0.514454  0.487966
# 35   0.421852  0.442934
# 46   0.238119  0.238776
# 112  0.412053  0.400878
# 141  0.547281  0.636657
# 94   0.412053  0.394158
# 31   0.460559  0.422278
# 66   0.314062  0.327069
# 30   0.299363  0.263932
# 41   0.421852  0.443744
# 13   0.421852  0.402793
# 92   0.225870  0.228243
# 10   0.539441  0.578473
# 91   0.396864  0.421579
# 120  0.386575  0.409975
# 148  0.067614  0.081088
# 2    0.299363  0.291325
# 68   0.314062  0.319884
# 86   0.271926  0.332224
# 131  0.551690  0.636657
# 122  0.343459  0.404538
# 123  0.547281  0.636657
# 134  1.000000  1.037650
# 124  0.637433  0.660275
# 39   0.494366  0.531489
# 22   0.539441  0.578598
# 25   0.460559  0.422278
# 155  0.014209  0.039244
# 43   0.505145  0.509470
# 64   0.231259  0.310396
# 104  0.514944  0.530139
# 110  0.412053  0.400878
# 119  0.551690  0.636657
# 76   0.271926  0.332224
# 149  0.000000  0.007587
# 71   0.333660  0.336797
# 54   0.243998  0.272422
# 153  0.000000  0.007462
# 20   0.475257  0.446042

# %%
df.head()
# Out:
#      Ship_name Cruise_line  Age  Tonnage  passengers  length  cabins
# 0      Journey     Azamara    6   30.277        6.94    5.94    3.55  \
# 1        Quest     Azamara    6   30.277        6.94    5.94    3.55
# 2  Celebration    Carnival   26   47.262       14.86    7.22    7.43
# 3     Conquest    Carnival   11  110.000       29.74    9.53   14.88
# 4      Destiny    Carnival   17  101.353       26.42    8.92   13.21
#
#    passenger_density   crew
# 0              42.64   3.55
# 1              42.64   3.55
# 2              31.80   6.70
# 3              36.99  19.10
# 4              38.36  10.00

# %%
df["crew"].unique()
# Out:
# array([ 3.55,  6.7 , 19.1 , 10.  ,  9.2 , 11.5 , 11.6 ,  6.6 ,  9.3 ,
#        10.3 , 10.29,  8.58,  9.99,  9.09,  0.6 ,  4.  ,  6.17,  6.36,
#        10.68,  3.85,  6.  , 10.9 ,  7.66,  5.45,  9.21, 12.53,  9.  ,
#         9.45,  8.  ,  5.57,  5.3 ,  8.42,  4.6 ,  6.44,  5.88,  5.61,
#         6.12,  5.31,  7.  , 13.13,  5.35,  9.87,  7.4 ,  2.97,  7.6 ,
#         4.7 , 11.  ,  6.14, 11.09,  4.38,  6.3 , 13.  ,  3.8 ,  9.59,
#         3.5 ,  8.69,  5.2 ,  8.5 ,  7.94, 12.2 , 12.  , 12.38, 11.1 ,
#         3.73,  6.96,  1.46,  4.45,  3.24,  2.11,  4.47, 11.85,  8.48,
#         6.71, 11.76, 13.6 ,  7.2 ,  8.22, 21.  ,  8.68,  7.65,  8.08,
#         1.6 ,  2.1 ,  2.95,  2.87,  1.97,  0.59,  6.8 ,  7.5 ,  0.88,
#         1.8 ])

# %%
plt.plot(df["Tonnage"])
plt.plot(df["passengers"])
plt.plot(df["length"])
plt.plot(df["cabins"])

plt.legend(["Tonnage", "passengers", "length", "cabins"])

plt.show()

# %%
# idx = len(df["crew"])
plt.plot(df["Tonnage"])
plt.plot(df["passengers"])
plt.plot(df["length"])
plt.plot(df["cabins"])

# plt.bar(df["crew"]*8, df["crew"]*8, color = "black")

plt.legend(["Tonnage", "passengers", "length", "cabins", "crew"])

plt.show()

# %%
plt.plot(df["crew"], color = "black")

# %%
x_pos = np.arange(len(df["crew"]))

plt.figure(figsize=(10, 6))
plt.plot(df["Tonnage"])
plt.plot(df["passengers"])
plt.plot(df["length"])
plt.plot(df["cabins"])

plt.bar(x_pos,df["crew"], color = "black")

plt.legend(["Tonnage", "passengers", "length", "cabins", "crew"])

plt.show()

# %%
print(len(df["crew"]))
# Out:
# 158

# %%
x_pos = np.arange(len(df["crew"]))
plt.bar(x_pos,df["crew"])

plt.show()
