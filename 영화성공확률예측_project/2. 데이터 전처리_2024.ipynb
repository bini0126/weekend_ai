# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # 기본 데이터 확인

# %%
df_2024 = pd.read_csv("./tmdb_v3_output/tmdb_2024.csv")
df_2024.head()
# Out:
#                      title release_date   type  runtime  season_count  \
# 0                   Utopia   2024-12-09  movie     93.0           NaN
# 1          Hunt the Wicked   2024-02-12  movie    103.0           NaN
# 2  The Roundup: Punishment   2024-04-24  movie    109.0           NaN
# 3      Life After Fighting   2024-06-07  movie    126.0           NaN
# 4                  Moana 2   2024-11-21  movie    100.0           NaN
#
#    episode_count                                       genre  \
# 0            NaN  Mystery, Thriller, Action, Science Fiction
# 1            NaN                                      Action
# 2            NaN      Action, Crime, Drama, Thriller, Comedy
# 3            NaN                     Action, Drama, Thriller
# 4            NaN        Animation, Adventure, Family, Comedy
#
#                                             director  \
# 0                                      James Bamford
# 1                                          Chris Huo
# 2                                   Heo Myeong-haeng
# 3                                        Bren Foster
# 4  David G. Derrick Jr., Jason Hand, Dana Ledoux ...
#
#                                                 cast country language  \
# 0  Moe Dunford, Charlotte Vega, Michael D. Xavier...      US       en
# 1  Xie Miao, Andy On, Andrew Lin Hoi, Hong Shuang...      CN       zh
# 2  Don Lee, Kim Moo-yul, Park Ji-hwan, Lee Dong-h...      KR       ko
# 3  Bren Foster, Cassie Howarth, Luke Ford, Annabe...      AU       en
# 4  Auliʻi Cravalho, Dwayne Johnson, Hualālai Chun...      US       en
#
#                                   production_company  \
# 0                                     SP Media Group
# 1                               Tencent Video, iQIYI
# 2  BA Entertainment, Hong Film, Big Punch Picture...
# 3   Blue Stone Media, Broken Yellow, Spinning Plates
# 4  Walt Disney Pictures, Walt Disney Animation St...
#
#                                             synopsis  \
# 0  A soldier searching for his missing wife break...
# 1  The film tells the story of narcotics police o...
# 2  'Monster Cop' Ma Seok-do investigates an illeg...
# 3  Retired martial arts world champion Alex Faulk...
# 4  After receiving an unexpected call from her wa...
#
#                                                 tags  imdb_rating  \
# 0                                       missing wife        5.136
# 1                                                 缉毒        4.800
# 2  casino, police, detective, sequel, illegal gam...        6.831
# 3                                     angry, anxious        6.944
# 4  sea, ocean, villain, musical, sequel, duringcr...        7.072
#
#    imdb_review_count
# 0                 33
# 1                  6
# 2                139
# 3                 36
# 4               2472

# %%
df_2024.sort_values(by='title', ascending=True).head(10)
# Out:
#                                                    title release_date   type  \
# 4235   "Auf der Alm da gibt's koa Sünd" - Die Erotikf...   2024-08-02  movie
# 17473  "FLOW THE CARNIVAL 2023 ~NARUTO SHIBARI~" SPECIAL   2024-02-07     tv
# 4806   "I Will Revenge This World With Love" - S. Par...   2024-08-28  movie
# 3378   "Les dents de la mer", l'histoire d'un succès ...   2024-12-16  movie
# 9120               #17 - To Finish The Barkley Marathons   2024-02-17  movie
# 12315                      #90’s - A Middle Class Biopic   2024-01-05     tv
# 1102                     #AMFAD: All My Friends Are Dead   2024-08-29  movie
# 9855                                               #BFFS   2024-02-01  movie
# 763                                          #Blue_Whale   2024-01-11  movie
# 17004                                              #Caso   2024-09-18     tv
#
#        runtime  season_count  episode_count                     genre  \
# 4235      48.0           NaN            NaN     Documentary, TV Movie
# 17473     60.0           1.0            1.0                       NaN
# 4806     110.0           NaN            NaN               Documentary
# 3378       NaN           NaN            NaN     Documentary, TV Movie
# 9120      63.0           NaN            NaN               Documentary
# 12315      NaN           1.0            6.0     Family, Comedy, Drama
# 1102      91.0           NaN            NaN  Horror, Comedy, Thriller
# 9855      57.0           NaN            NaN                       NaN
# 763       95.0           NaN            NaN          Horror, Thriller
# 17004      NaN           1.0            7.0               Documentary
#
#                                   director  \
# 4235                           Otto Retzer
# 17473                                  NaN
# 4806                             Zara Jian
# 3378      Antoine Coursat, Olivier Bonnard
# 9120      Fabien Duflos, Alice Duval-Barré
# 12315                         Aditya Hasan
# 1102                        Marcus Dunstan
# 9855   Mya Speller Cullins, Terry T. Miles
# 763                          Anna Zaytseva
# 17004                                  NaN
#
#                                                     cast     country language  \
# 4235   Rinaldo Talamonti, Christine Schuberth, Isa Ha...          AT       de
# 17473                                                NaN          JP       ja
# 4806   Emir Kusturica, Joël Chapron, Artavazd Peleshi...  AM, FR, GB       hy
# 3378   Steven Spielberg, Lorraine Gary, Joe Alves, Ca...          FR       fr
# 9120   Karel Sabbe, Lazarus Lake, Joe McConaughy, Joh...          BE       en
# 12315  Sivaji Sontineni, Vasuki Anand, Mouli, Vasanth...          IN       te
# 1102   Jade Pettyjohn, JoJo Siwa, Jennifer Ens, Ali F...          US       en
# 9855   Xica Brewer, Terry T. Miles, Marley Peek, Summ...          US       en
# 763    Anna Potebnya, Timofey Eletskiy, Ekaterina Stu...          RU       ru
# 17004          Carlos Quílez, Beatriz Osa, Cruz Morcillo          ES       es
#
#                                       production_company  \
# 4235                          Lisa Film, ORF, Melodie TV
# 17473                                    Space Shower TV
# 4806   Boomerang Media .am, Ava films, La Huit, David...
# 3378                                    CAPA, ARTE, RTBF
# 9120                                       Tangram Films
# 12315                                                NaN
# 1102   Roundtable Entertainment, Digital Riot Media, ...
# 9855                                  TerMya Productions
# 763                            Bazelevs Production, KION
# 17004                               La Sexta, Atresmedia
#
#                                                 synopsis  \
# 4235   In the 1960s, the film production company Lisa...
# 17473  Broadcasting the tour for the album "FLOW THE ...
# 4806   The author of the film decides to leave the co...
# 3378   In the summer of 1975, the young director Stev...
# 9120   An unprecedented look into the psyche of Karel...
# 12315  A nostalgic trip down memory lane, delving int...
# 1102   A group of college friends rent an Airbnb for ...
# 9855   What's done in the dark, is always brought to ...
# 763    Rebellious schoolgirl Dana grieves for her you...
# 17004                                                NaN
#
#                                                     tags  imdb_rating  \
# 4235                              german cinema, erotica        0.000
# 17473                                                NaN        0.000
# 4806   interview, archive footage, old footage, portr...        0.000
# 3378   cinema on cinema, movie business, social docum...        6.700
# 9120   belgium, endurance, barkley marathons, ultra r...        5.000
# 12315                                                NaN        8.200
# 1102   serial killer, college student, college friend...        5.647
# 9855                                                 NaN        0.000
# 763           found footage, internet legend, screenlife        6.300
# 17004                                                NaN       10.000
#
#        imdb_review_count
# 4235                   0
# 17473                  0
# 4806                   1
# 3378                   3
# 9120                   1
# 12315                  4
# 1102                  34
# 9855                   0
# 763                   85
# 17004                  1

# %%
df_2024.isnull().sum()
# Out:
# title                     0
# release_date              0
# type                      0
# runtime                8694
# season_count           9998
# episode_count          9998
# genre                  3732
# director               7708
# cast                   4436
# country                  35
# language                  0
# production_company     7647
# synopsis               5211
# tags                  15562
# imdb_rating               0
# imdb_review_count         0
# dtype: int64

# %% [markdown]
# # 2. 전처리 전처리_type

# %%
df_2024[df_2024['season_count'].isna() & df_2024['episode_count'].isna()].head(5)
# Out:
#                      title release_date   type  runtime  season_count  \
# 0                   Utopia   2024-12-09  movie     93.0           NaN
# 1          Hunt the Wicked   2024-02-12  movie    103.0           NaN
# 2  The Roundup: Punishment   2024-04-24  movie    109.0           NaN
# 3      Life After Fighting   2024-06-07  movie    126.0           NaN
# 4                  Moana 2   2024-11-21  movie    100.0           NaN
#
#    episode_count                                       genre  \
# 0            NaN  Mystery, Thriller, Action, Science Fiction
# 1            NaN                                      Action
# 2            NaN      Action, Crime, Drama, Thriller, Comedy
# 3            NaN                     Action, Drama, Thriller
# 4            NaN        Animation, Adventure, Family, Comedy
#
#                                             director  \
# 0                                      James Bamford
# 1                                          Chris Huo
# 2                                   Heo Myeong-haeng
# 3                                        Bren Foster
# 4  David G. Derrick Jr., Jason Hand, Dana Ledoux ...
#
#                                                 cast country language  \
# 0  Moe Dunford, Charlotte Vega, Michael D. Xavier...      US       en
# 1  Xie Miao, Andy On, Andrew Lin Hoi, Hong Shuang...      CN       zh
# 2  Don Lee, Kim Moo-yul, Park Ji-hwan, Lee Dong-h...      KR       ko
# 3  Bren Foster, Cassie Howarth, Luke Ford, Annabe...      AU       en
# 4  Auliʻi Cravalho, Dwayne Johnson, Hualālai Chun...      US       en
#
#                                   production_company  \
# 0                                     SP Media Group
# 1                               Tencent Video, iQIYI
# 2  BA Entertainment, Hong Film, Big Punch Picture...
# 3   Blue Stone Media, Broken Yellow, Spinning Plates
# 4  Walt Disney Pictures, Walt Disney Animation St...
#
#                                             synopsis  \
# 0  A soldier searching for his missing wife break...
# 1  The film tells the story of narcotics police o...
# 2  'Monster Cop' Ma Seok-do investigates an illeg...
# 3  Retired martial arts world champion Alex Faulk...
# 4  After receiving an unexpected call from her wa...
#
#                                                 tags  imdb_rating  \
# 0                                       missing wife        5.136
# 1                                                 缉毒        4.800
# 2  casino, police, detective, sequel, illegal gam...        6.831
# 3                                     angry, anxious        6.944
# 4  sea, ocean, villain, musical, sequel, duringcr...        7.072
#
#    imdb_review_count
# 0                 33
# 1                  6
# 2                139
# 3                 36
# 4               2472

# %%
df_2024[df_2024['season_count'].isna() & df_2024['episode_count'].isna()].shape
# Out:
# (9998, 16)

# %%
df_2024['type'].value_counts(dropna=False)
# Out:
# type
# movie    9998
# tv       9998
# Name: count, dtype: int64

# %%
print(df_2024[df_2024['type'] == 'movie']['season_count'].value_counts(dropna=False))
print(df_2024[df_2024['type'] == 'movie']['episode_count'].value_counts(dropna=False))
# Out:
# season_count
# NaN    9998
# Name: count, dtype: int64
# episode_count
# NaN    9998
# Name: count, dtype: int64

# %%
print(df_2024[df_2024['type'] == 'tv']['season_count'].value_counts(dropna=False))
# Out:
# season_count
# 1.0     9232
# 2.0      674
# 3.0       53
# 4.0       13
# 5.0        9
# 6.0        5
# 7.0        3
# 10.0       2
# 9.0        2
# 11.0       1
# 24.0       1
# 15.0       1
# 13.0       1
# 21.0       1
# Name: count, dtype: int64

# %%
print(df_2024[df_2024['type'] == 'tv']['episode_count'].value_counts(dropna=False))
# Out:
# episode_count
# 1.0      2295
# 6.0       951
# 8.0       812
# 4.0       648
# 10.0      589
#          ...
# 200.0       1
# 267.0       1
# 215.0       1
# 149.0       1
# 73.0        1
# Name: count, Length: 166, dtype: int64

# %%
df_2024_1 = df_2024

# %%
# movie인 경우 season/episode count가 NaN이면 1로 채움
df_2024_1.loc[df_2024_1['type'] == 'movie', ['season_count', 'episode_count']] = df_2024_1.loc[df_2024_1['type'] == 'movie', ['season_count', 'episode_count']].fillna(1)
pd.set_option('display.max_columns', None)
df_2024_1.head()
# Out:
#                      title release_date   type  runtime  season_count  \
# 0                   Utopia   2024-12-09  movie     93.0           1.0
# 1          Hunt the Wicked   2024-02-12  movie    103.0           1.0
# 2  The Roundup: Punishment   2024-04-24  movie    109.0           1.0
# 3      Life After Fighting   2024-06-07  movie    126.0           1.0
# 4                  Moana 2   2024-11-21  movie    100.0           1.0
#
#    episode_count                                       genre  \
# 0            1.0  Mystery, Thriller, Action, Science Fiction
# 1            1.0                                      Action
# 2            1.0      Action, Crime, Drama, Thriller, Comedy
# 3            1.0                     Action, Drama, Thriller
# 4            1.0        Animation, Adventure, Family, Comedy
#
#                                             director  \
# 0                                      James Bamford
# 1                                          Chris Huo
# 2                                   Heo Myeong-haeng
# 3                                        Bren Foster
# 4  David G. Derrick Jr., Jason Hand, Dana Ledoux ...
#
#                                                 cast country language  \
# 0  Moe Dunford, Charlotte Vega, Michael D. Xavier...      US       en
# 1  Xie Miao, Andy On, Andrew Lin Hoi, Hong Shuang...      CN       zh
# 2  Don Lee, Kim Moo-yul, Park Ji-hwan, Lee Dong-h...      KR       ko
# 3  Bren Foster, Cassie Howarth, Luke Ford, Annabe...      AU       en
# 4  Auliʻi Cravalho, Dwayne Johnson, Hualālai Chun...      US       en
#
#                                   production_company  \
# 0                                     SP Media Group
# 1                               Tencent Video, iQIYI
# 2  BA Entertainment, Hong Film, Big Punch Picture...
# 3   Blue Stone Media, Broken Yellow, Spinning Plates
# 4  Walt Disney Pictures, Walt Disney Animation St...
#
#                                             synopsis  \
# 0  A soldier searching for his missing wife break...
# 1  The film tells the story of narcotics police o...
# 2  'Monster Cop' Ma Seok-do investigates an illeg...
# 3  Retired martial arts world champion Alex Faulk...
# 4  After receiving an unexpected call from her wa...
#
#                                                 tags  imdb_rating  \
# 0                                       missing wife        5.136
# 1                                                 缉毒        4.800
# 2  casino, police, detective, sequel, illegal gam...        6.831
# 3                                     angry, anxious        6.944
# 4  sea, ocean, villain, musical, sequel, duringcr...        7.072
#
#    imdb_review_count
# 0                 33
# 1                  6
# 2                139
# 3                 36
# 4               2472

# %%
df_2024[(df_2024['type'] == 'tv') & (df_2024['season_count'].isna() | df_2024['episode_count'].isna())]
#df_2024[(df_2024['type'] == 'movie') & (df_2024['season_count'].isna() | df_2024['episode_count'].isna())]
# Out:
# Empty DataFrame
# Columns: [title, release_date, type, runtime, season_count, episode_count, genre, director, cast, country, language, production_company, synopsis, tags, imdb_rating, imdb_review_count]
# Index: []

# %%
print(df_2024_1[df_2024_1['season_count'] == 1.0]['episode_count'].value_counts(dropna=False))
# Out:
# episode_count
# 1.0      12272
# 6.0        922
# 8.0        766
# 4.0        635
# 10.0       552
#          ...
# 93.0         1
# 57.0         1
# 126.0        1
# 105.0        1
# 98.0         1
# Name: count, Length: 141, dtype: int64

# %%
print(df_2024_1[df_2024_1['episode_count'] == 1.0]['season_count'].value_counts(dropna=False))
# Out:
# season_count
# 1.0     12272
# 2.0        12
# 3.0         2
# 15.0        1
# 13.0        1
# 21.0        1
# 6.0         1
# 5.0         1
# 10.0        1
# 4.0         1
# Name: count, dtype: int64

# %%
df_2024_2 = df_2024_1
df_2024_2.loc[df_2024_2['type'] == 'tv', ['season_count', 'episode_count']] = df_2024_2.loc[df_2024_1['type'] == 'tv', ['season_count', 'episode_count']].fillna(1)
pd.set_option('display.max_columns', None)
df_2024_2.head()
# Out:
#                      title release_date   type  runtime  season_count  \
# 0                   Utopia   2024-12-09  movie     93.0           1.0
# 1          Hunt the Wicked   2024-02-12  movie    103.0           1.0
# 2  The Roundup: Punishment   2024-04-24  movie    109.0           1.0
# 3      Life After Fighting   2024-06-07  movie    126.0           1.0
# 4                  Moana 2   2024-11-21  movie    100.0           1.0
#
#    episode_count                                       genre  \
# 0            1.0  Mystery, Thriller, Action, Science Fiction
# 1            1.0                                      Action
# 2            1.0      Action, Crime, Drama, Thriller, Comedy
# 3            1.0                     Action, Drama, Thriller
# 4            1.0        Animation, Adventure, Family, Comedy
#
#                                             director  \
# 0                                      James Bamford
# 1                                          Chris Huo
# 2                                   Heo Myeong-haeng
# 3                                        Bren Foster
# 4  David G. Derrick Jr., Jason Hand, Dana Ledoux ...
#
#                                                 cast country language  \
# 0  Moe Dunford, Charlotte Vega, Michael D. Xavier...      US       en
# 1  Xie Miao, Andy On, Andrew Lin Hoi, Hong Shuang...      CN       zh
# 2  Don Lee, Kim Moo-yul, Park Ji-hwan, Lee Dong-h...      KR       ko
# 3  Bren Foster, Cassie Howarth, Luke Ford, Annabe...      AU       en
# 4  Auliʻi Cravalho, Dwayne Johnson, Hualālai Chun...      US       en
#
#                                   production_company  \
# 0                                     SP Media Group
# 1                               Tencent Video, iQIYI
# 2  BA Entertainment, Hong Film, Big Punch Picture...
# 3   Blue Stone Media, Broken Yellow, Spinning Plates
# 4  Walt Disney Pictures, Walt Disney Animation St...
#
#                                             synopsis  \
# 0  A soldier searching for his missing wife break...
# 1  The film tells the story of narcotics police o...
# 2  'Monster Cop' Ma Seok-do investigates an illeg...
# 3  Retired martial arts world champion Alex Faulk...
# 4  After receiving an unexpected call from her wa...
#
#                                                 tags  imdb_rating  \
# 0                                       missing wife        5.136
# 1                                                 缉毒        4.800
# 2  casino, police, detective, sequel, illegal gam...        6.831
# 3                                     angry, anxious        6.944
# 4  sea, ocean, villain, musical, sequel, duringcr...        7.072
#
#    imdb_review_count
# 0                 33
# 1                  6
# 2                139
# 3                 36
# 4               2472

# %% [markdown]
# # 2. 데이터 전처리_runtime

# %%
df_2024_2.isnull().sum()
# Out:
# title                     0
# release_date              0
# type                      0
# runtime                8694
# season_count              0
# episode_count             0
# genre                  3732
# director               7708
# cast                   4436
# country                  35
# language                  0
# production_company     7647
# synopsis               5211
# tags                  15562
# imdb_rating               0
# imdb_review_count         0
# dtype: int64

# %%
df_2024_2.shape
# Out:
# (19996, 16)

# %%
df_2024_2[df_2024_2['runtime'].isna() & df_2024_2['genre'].isna() ].shape
# Out:
# (3036, 16)

# %% [markdown]
# ## 2_2 runtime null 값 열 제거

# %%
df_2024_3 = df_2024_2

# %%
df_2024_3.dropna(subset=['runtime'], inplace=True)

# %%
df_2024_3.shape
# Out:
# (11302, 16)

# %% [markdown]
# # 2. 데이터 전처리_pr

# %%
df_2024_4 = df_2024_3
df_2024_4
# Out:
#                                                    title release_date   type  \
# 0                                                 Utopia   2024-12-09  movie
# 1                                        Hunt the Wicked   2024-02-12  movie
# 2                                The Roundup: Punishment   2024-04-24  movie
# 3                                    Life After Fighting   2024-06-07  movie
# 4                                                Moana 2   2024-11-21  movie
# ...                                                  ...          ...    ...
# 19863                                  Safe i Safe house   2024-09-06     tv
# 19873                                            国宝迷踪第一季   2024-08-12     tv
# 19893  MAZZEL“TEA TIMES” ~1st Album "Parade" Release ...   2024-03-25     tv
# 19955                                             Kaninn   2024-11-25     tv
# 19984            Google Pixel | au #Visual Studio & Live   2024-04-03     tv
#
#        runtime  season_count  episode_count  \
# 0         93.0           1.0            1.0
# 1        103.0           1.0            1.0
# 2        109.0           1.0            1.0
# 3        126.0           1.0            1.0
# 4        100.0           1.0            1.0
# ...        ...           ...            ...
# 19863     20.0           1.0            1.0
# 19873     40.0           1.0            4.0
# 19893     30.0           1.0            1.0
# 19955     40.0           1.0            2.0
# 19984     60.0           1.0            1.0
#
#                                             genre  \
# 0      Mystery, Thriller, Action, Science Fiction
# 1                                          Action
# 2          Action, Crime, Drama, Thriller, Comedy
# 3                         Action, Drama, Thriller
# 4            Animation, Adventure, Family, Comedy
# ...                                           ...
# 19863                                 Documentary
# 19873                          Documentary, Crime
# 19893                                         NaN
# 19955                                 Documentary
# 19984                                         NaN
#
#                                                 director  \
# 0                                          James Bamford
# 1                                              Chris Huo
# 2                                       Heo Myeong-haeng
# 3                                            Bren Foster
# 4      David G. Derrick Jr., Jason Hand, Dana Ledoux ...
# ...                                                  ...
# 19863                                                NaN
# 19873                                                NaN
# 19893                                                NaN
# 19955                                                NaN
# 19984                                                NaN
#
#                                                     cast country language  \
# 0      Moe Dunford, Charlotte Vega, Michael D. Xavier...      US       en
# 1      Xie Miao, Andy On, Andrew Lin Hoi, Hong Shuang...      CN       zh
# 2      Don Lee, Kim Moo-yul, Park Ji-hwan, Lee Dong-h...      KR       ko
# 3      Bren Foster, Cassie Howarth, Luke Ford, Annabe...      AU       en
# 4      Auliʻi Cravalho, Dwayne Johnson, Hualālai Chun...      US       en
# ...                                                  ...     ...      ...
# 19863                                                NaN      DK       da
# 19873                                                NaN      CN       zh
# 19893                                                NaN      JP       ja
# 19955                                                NaN      IS       is
# 19984                                                NaN      JP       ja
#
#                                       production_company  \
# 0                                         SP Media Group
# 1                                   Tencent Video, iQIYI
# 2      BA Entertainment, Hong Film, Big Punch Picture...
# 3       Blue Stone Media, Broken Yellow, Spinning Plates
# 4      Walt Disney Pictures, Walt Disney Animation St...
# ...                                                  ...
# 19863                                               TV 2
# 19873                                           bilibili
# 19893                                    Space Shower TV
# 19955                                                NaN
# 19984                                    Space Shower TV
#
#                                                 synopsis  \
# 0      A soldier searching for his missing wife break...
# 1      The film tells the story of narcotics police o...
# 2      'Monster Cop' Ma Seok-do investigates an illeg...
# 3      Retired martial arts world champion Alex Faulk...
# 4      After receiving an unexpected call from her wa...
# ...                                                  ...
# 19863                                                NaN
# 19873                                                NaN
# 19893  The 5th installment of the 7-month series is a...
# 19955  Icelandic basketball has, since the 1970s, bee...
# 19984  An event held in Harajuku and Omotesando, Toky...
#
#                                                     tags  imdb_rating  \
# 0                                           missing wife        5.136
# 1                                                     缉毒        4.800
# 2      casino, police, detective, sequel, illegal gam...        6.831
# 3                                         angry, anxious        6.944
# 4      sea, ocean, villain, musical, sequel, duringcr...        7.072
# ...                                                  ...          ...
# 19863                                                NaN       10.000
# 19873                                                NaN        0.000
# 19893                                                NaN        0.000
# 19955                                                NaN        0.000
# 19984                                                NaN        0.000
#
#        imdb_review_count
# 0                     33
# 1                      6
# 2                    139
# 3                     36
# 4                   2472
# ...                  ...
# 19863                  1
# 19873                  0
# 19893                  0
# 19955                  0
# 19984                  0
#
# [11302 rows x 16 columns]

# %%
df_2024_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11302 entries, 0 to 19984
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               11302 non-null  object
#  1   release_date        11302 non-null  object
#  2   type                11302 non-null  object
#  3   runtime             11302 non-null  float64
#  4   season_count        11302 non-null  float64
#  5   episode_count       11302 non-null  float64
#  6   genre               10606 non-null  object
#  7   director            9580 non-null   object
#  8   cast                10299 non-null  object
#  9   country             11291 non-null  object
#  10  language            11302 non-null  object
#  11  production_company  8523 non-null   object
#  12  synopsis            10478 non-null  object
#  13  tags                4080 non-null   object
#  14  imdb_rating         11302 non-null  float64
#  15  imdb_review_count   11302 non-null  int64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 1.5+ MB

# %% [markdown]
# ### tags 관련 기본 문제 해결

# %% [markdown]
# 1) synopsis, tags, genre가 모두 NaN인 데이터 모두 제거

# %%
# 1. 세기: synopsis, genre가 모두 NaN인 행 개수
nan_rows = df_2024_4[['synopsis', 'genre']].isna().all(axis=1)
count_nan_rows = nan_rows.sum()
print(f"synopsis, genre가 모두 NaN인 행 개수: {count_nan_rows}")
# Out:
# synopsis, genre가 모두 NaN인 행 개수: 115

# %%
# 2. 삭제: 그런 행 삭제
df_2024_4_cleaned = df_2024_4.loc[~nan_rows].copy()

# %%
df_2024_4 = df_2024_4.loc[~nan_rows].copy()
df_2024_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11187 entries, 0 to 19984
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               11187 non-null  object
#  1   release_date        11187 non-null  object
#  2   type                11187 non-null  object
#  3   runtime             11187 non-null  float64
#  4   season_count        11187 non-null  float64
#  5   episode_count       11187 non-null  float64
#  6   genre               10606 non-null  object
#  7   director            9548 non-null   object
#  8   cast                10228 non-null  object
#  9   country             11176 non-null  object
#  10  language            11187 non-null  object
#  11  production_company  8488 non-null   object
#  12  synopsis            10478 non-null  object
#  13  tags                4080 non-null   object
#  14  imdb_rating         11187 non-null  float64
#  15  imdb_review_count   11187 non-null  int64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 1.5+ MB

# %%
df_2024_4
# Out:
#                                                    title release_date   type  \
# 0                                                 Utopia   2024-12-09  movie
# 1                                        Hunt the Wicked   2024-02-12  movie
# 2                                The Roundup: Punishment   2024-04-24  movie
# 3                                    Life After Fighting   2024-06-07  movie
# 4                                                Moana 2   2024-11-21  movie
# ...                                                  ...          ...    ...
# 19863                                  Safe i Safe house   2024-09-06     tv
# 19873                                            国宝迷踪第一季   2024-08-12     tv
# 19893  MAZZEL“TEA TIMES” ~1st Album "Parade" Release ...   2024-03-25     tv
# 19955                                             Kaninn   2024-11-25     tv
# 19984            Google Pixel | au #Visual Studio & Live   2024-04-03     tv
#
#        runtime  season_count  episode_count  \
# 0         93.0           1.0            1.0
# 1        103.0           1.0            1.0
# 2        109.0           1.0            1.0
# 3        126.0           1.0            1.0
# 4        100.0           1.0            1.0
# ...        ...           ...            ...
# 19863     20.0           1.0            1.0
# 19873     40.0           1.0            4.0
# 19893     30.0           1.0            1.0
# 19955     40.0           1.0            2.0
# 19984     60.0           1.0            1.0
#
#                                             genre  \
# 0      Mystery, Thriller, Action, Science Fiction
# 1                                          Action
# 2          Action, Crime, Drama, Thriller, Comedy
# 3                         Action, Drama, Thriller
# 4            Animation, Adventure, Family, Comedy
# ...                                           ...
# 19863                                 Documentary
# 19873                          Documentary, Crime
# 19893                                         NaN
# 19955                                 Documentary
# 19984                                         NaN
#
#                                                 director  \
# 0                                          James Bamford
# 1                                              Chris Huo
# 2                                       Heo Myeong-haeng
# 3                                            Bren Foster
# 4      David G. Derrick Jr., Jason Hand, Dana Ledoux ...
# ...                                                  ...
# 19863                                                NaN
# 19873                                                NaN
# 19893                                                NaN
# 19955                                                NaN
# 19984                                                NaN
#
#                                                     cast country language  \
# 0      Moe Dunford, Charlotte Vega, Michael D. Xavier...      US       en
# 1      Xie Miao, Andy On, Andrew Lin Hoi, Hong Shuang...      CN       zh
# 2      Don Lee, Kim Moo-yul, Park Ji-hwan, Lee Dong-h...      KR       ko
# 3      Bren Foster, Cassie Howarth, Luke Ford, Annabe...      AU       en
# 4      Auliʻi Cravalho, Dwayne Johnson, Hualālai Chun...      US       en
# ...                                                  ...     ...      ...
# 19863                                                NaN      DK       da
# 19873                                                NaN      CN       zh
# 19893                                                NaN      JP       ja
# 19955                                                NaN      IS       is
# 19984                                                NaN      JP       ja
#
#                                       production_company  \
# 0                                         SP Media Group
# 1                                   Tencent Video, iQIYI
# 2      BA Entertainment, Hong Film, Big Punch Picture...
# 3       Blue Stone Media, Broken Yellow, Spinning Plates
# 4      Walt Disney Pictures, Walt Disney Animation St...
# ...                                                  ...
# 19863                                               TV 2
# 19873                                           bilibili
# 19893                                    Space Shower TV
# 19955                                                NaN
# 19984                                    Space Shower TV
#
#                                                 synopsis  \
# 0      A soldier searching for his missing wife break...
# 1      The film tells the story of narcotics police o...
# 2      'Monster Cop' Ma Seok-do investigates an illeg...
# 3      Retired martial arts world champion Alex Faulk...
# 4      After receiving an unexpected call from her wa...
# ...                                                  ...
# 19863                                                NaN
# 19873                                                NaN
# 19893  The 5th installment of the 7-month series is a...
# 19955  Icelandic basketball has, since the 1970s, bee...
# 19984  An event held in Harajuku and Omotesando, Toky...
#
#                                                     tags  imdb_rating  \
# 0                                           missing wife        5.136
# 1                                                     缉毒        4.800
# 2      casino, police, detective, sequel, illegal gam...        6.831
# 3                                         angry, anxious        6.944
# 4      sea, ocean, villain, musical, sequel, duringcr...        7.072
# ...                                                  ...          ...
# 19863                                                NaN       10.000
# 19873                                                NaN        0.000
# 19893                                                NaN        0.000
# 19955                                                NaN        0.000
# 19984                                                NaN        0.000
#
#        imdb_review_count
# 0                     33
# 1                      6
# 2                    139
# 3                     36
# 4                   2472
# ...                  ...
# 19863                  1
# 19873                  0
# 19893                  0
# 19955                  0
# 19984                  0
#
# [11187 rows x 16 columns]

# %% [markdown]
# ## director와 cast가 모두 nan인 행 제거

# %%
nan_both = df_2024_4[(df_2024_4['director'].isna()) & (df_2024_4['cast'].isna())]
print(f"director와 cast 둘 다 NaN인 행 개수: {len(nan_both)}")
# Out:
# director와 cast 둘 다 NaN인 행 개수: 329

# %%
df_2024_4 = df_2024_4.dropna(subset=['director', 'cast'], how='all')

# %%
df_2024_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10858 entries, 0 to 19616
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               10858 non-null  object
#  1   release_date        10858 non-null  object
#  2   type                10858 non-null  object
#  3   runtime             10858 non-null  float64
#  4   season_count        10858 non-null  float64
#  5   episode_count       10858 non-null  float64
#  6   genre               10358 non-null  object
#  7   director            9548 non-null   object
#  8   cast                10228 non-null  object
#  9   country             10848 non-null  object
#  10  language            10858 non-null  object
#  11  production_company  8289 non-null   object
#  12  synopsis            10241 non-null  object
#  13  tags                4071 non-null   object
#  14  imdb_rating         10858 non-null  float64
#  15  imdb_review_count   10858 non-null  int64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 1.4+ MB

# %% [markdown]
# # tag npl처리

# %%
# 1. tags 결측치는 빈 문자열로 대체
df_2024_4['tags'] = df_2024_4['tags'].fillna('')

# 2. synopsis, genre 결측치 처리 후 text_input 생성
df_2024_4['synopsis'] = df_2024_4['synopsis'].fillna('')
df_2024_4['genre'] = df_2024_4['genre'].fillna('')
df_2024_4['text_input'] = df_2024_4['synopsis'] + ' ' + df_2024_4['genre']

# 3. tags 기준으로 train / test 나누기
train_df = df_2024_4[df_2024_4['tags'] != ''].copy()
test_df = df_2024_4[df_2024_4['tags'] == ''].copy()

# 4. tags 리스트로 분리
train_df['tags_list'] = train_df['tags'].apply(lambda x: x.split(','))

# 5. 다중 라벨 인코딩
mlb = MultiLabelBinarizer()
y_train = mlb.fit_transform(train_df['tags_list'])

# 6. 텍스트 벡터화 (TF-IDF)
vectorizer = TfidfVectorizer(max_features=5000)
X_train = vectorizer.fit_transform(train_df['text_input'])

# 7. 모델 학습 (LogisticRegression 다중 라벨)
model = OneVsRestClassifier(LogisticRegression(max_iter=1000))
model.fit(X_train, y_train)

# 8. 예측 대상(test_df)이 비어있지 않으면 예측 수행
if not test_df.empty:
    X_test = vectorizer.transform(test_df['text_input'])
    y_prob = model.predict_proba(X_test)

    # 예측 임계값 설정 (낮춰서 태그 생성 늘림)
    threshold = 0.07
    y_pred = (y_prob >= threshold).astype(int)

    predicted_tags = mlb.inverse_transform(y_pred)
    test_df['predicted_tags'] = [', '.join(tags) if tags else np.nan for tags in predicted_tags]

    # 9. 규칙 기반 태그 보완용 키워드 룰 정의
    rules = {
        'romance': ['romance', 'love', 'relationship', 'affair', 'heart', 'kiss', 'wedding',
                    'boyfriend', 'girlfriend', 'breakup', 'dating', 'first love',
                    'valentine', 'romantic', 'jealousy', 'intimacy', 'honeymoon'],
        'action': ['battle', 'war', 'fight', 'soldier', 'gun', 'explosion', 'chase', 'enemy',
                'car chase', 'explosives', 'gunfight', 'hand-to-hand', 'sniper',
                'ambush', 'mercenary', 'adrenaline', 'combat', 'high-octane'],
        'thriller': ['thriller', 'mystery', 'suspense', 'crime', 'killer', 'murder', 'detective',
                    'interrogation', 'conspiracy', 'mind game', 'tension', 'abduction',
                    'dangerous', 'mind-bending', 'ticking clock', 'trap'],
        'comedy': ['comedy', 'funny', 'humor', 'laugh', 'joke', 'parody',
                'sitcom', 'sarcasm', 'one-liner', 'slapstick', 'banter',
                'awkward moment', 'gag', 'prank', 'hilarity'],
        'horror': ['ghost', 'horror', 'zombie', 'demon', 'vampire', 'curse',
                'haunted', 'scream', 'paranormal', 'supernatural', 'bloodcurdling',
                'creepy', 'terrifying', 'evil spirit', 'possessed', 'ritual'],
        'fantasy': ['magic', 'wizard', 'dragon', 'kingdom', 'mythical',
                    'sorcerer', 'enchanted', 'portal', 'spell', 'epic quest',
                    'mystical creature', 'ancient prophecy', 'grimoire'],
        'sci-fi': ['space', 'alien', 'robot', 'future', 'technology', 'sci-fi', 'cyber',
                'cyborg', 'AI uprising', 'time machine', 'spaceship', 'hyperspace',
                'galaxy', 'terraforming', 'futuristic', 'parallel universe', 'bioengineering'],
        'drama': ['family', 'life', 'struggle', 'emotional', 'drama', 'society',
                'inner struggle', 'self-discovery', 'character driven', 'emotional arc',
                'breakdown', 'life lesson', 'interpersonal', 'catharsis'],
        'crime': ['criminal', 'robbery', 'heist', 'mafia', 'gang',
                'heist', 'detective', 'undercover', 'criminal syndicate',
                'drug cartel', 'interrogation room', 'forensics', 'manhunt'],
        'animation': ['animation', 'cartoon', 'drawn', 'animated'],
        'sports': ['sports', 'football', 'basketball', 'coach', 'tournament'],
        'historical': ['king', 'queen', 'dynasty', 'empire', 'history', 'ancient'],
        'adventure': ['journey', 'quest', 'treasure', 'explore', 'island', 'survival'],
        'musical': ['song', 'singing', 'performance', 'dance', 'stage', 'music'],
        'documentary': ['real', 'true story', 'interview', 'archive', 'biography', 'footage'],
        'psychological': ['mind', 'mental', 'insanity', 'delusion', 'subconscious', 'dream'],
        'superhero': ['hero', 'superpower', 'villain', 'save', 'city', 'mask'],
        'noir': ['detective', 'dark', 'cigarette', 'femme fatale', 'shadow', 'monologue'],
        'family': ['parent', 'child', 'home', 'holiday', 'siblings', 'bond'],
        'rom-com': ['love', 'funny', 'awkward', 'date', 'charm', 'happy ending'],
        'military': ['army', 'navy', 'mission', 'rank', 'base', 'operation'],
        'cyberpunk': ['neon', 'hacker', 'corporation', 'dystopia', 'implant', 'surveillance'],
        'post-apocalyptic': ['ruins', 'survivor', 'radiation', 'collapse', 'tribe', 'scavenge'],
        'teen': ['high school', 'prom', 'friendship', 'coming of age', 'crush', 'rebellion'],
        'feel-good': ['inspiring', 'heartwarming', 'uplifting', 'positive', 'hope', 'smile'],
        'dark': ['depressing', 'grim', 'tragic', 'bleak', 'morbid'],
        'female-lead': ['strong woman', 'heroine', 'female protagonist', 'girl power'],
        'twist': ['plot twist', 'unpredictable', 'reveal', 'surprise ending'],
        'based-on-true-story': ['true story', 'biopic', 'real events', 'true events'],
        'underdog': ['struggle', 'rise', 'overcome', 'unlikely hero', 'against all odds'],
        'ensemble': ['many characters', 'multiple leads', 'group dynamic', 'interwoven stories'],
        'nostalgic': ['retro', 'classic', 'throwback', '80s', '90s', 'childhood'],
        'social-issue': ['racism', 'inequality', 'poverty', 'justice', 'activism'],
        'trending-theme': ['AI', 'climate', 'pandemic', 'influencer', 'metaverse'],
        'revenge': ['revenge', 'vengeance', 'payback', 'retaliation', 'score to settle'],
        'detective': ['detective', 'investigation', 'clues', 'case', 'inspector', 'sleuth'],
        'time-travel': ['time travel', 'time loop', 'past and future', 'timeline', 'chronosphere'],
        'courtroom': ['courtroom', 'trial', 'lawyer', 'judge', 'defendant', 'testimony'],
        'survival': ['survival', 'wilderness', 'isolation', 'extreme conditions', 'barely escape'],
        'espionage': ['spy', 'espionage', 'agent', 'undercover', 'intel', 'classified'],
        'campus': ['college', 'campus', 'lecture hall', 'seniors', 'dorm', 'professor'],
        'startup': ['startup', 'entrepreneur', 'founder', 'venture', 'pitching', 'angel investor'],
        'heist': ['heist', 'robbery', 'master plan', 'getaway', 'vault', 'crew'],
        'royalty': ['prince', 'princess', 'royal', 'crown', 'throne', 'palace'],
        'wuxia': ['martial arts', 'swordplay', 'wuxia', 'clan', 'sect', 'inner energy'],
        'idol': ['idol', 'stage', 'fandom', 'trainee', 'debut', 'fan meeting'],
        'political': ['election', 'politics', 'scandal', 'congress', 'corruption', 'regime'],
        'revenge-romance': ['bitter love', 'masked identity', 'burning passion', 'payback with love'],
        'healing-romance': ['gentle romance', 'emotional support', 'quiet relationship', 'warm affection'],
        'coming-of-age': ['self-discovery', 'growing up', 'teenage years', 'puberty',
                        'youth', 'maturity', 'identity', 'high school', 'first time', 'life lessons'],
        'dark-comedy': ['dark humor', 'macabre laugh', 'twisted joke', 'morbidly funny',
                        'ironic death', 'satirical tragedy', 'deadpan', 'black comedy'],
        'dystopian': ['oppressive regime', 'totalitarian', 'no freedom', 'surveillance state',
                    'rebellion', 'social collapse', 'harsh world', 'authoritarian', 'controlled society'],
        'slice-of-life': ['daily routine', 'ordinary moments', 'casual life', 'everyday drama',
                        'subtle emotion', 'mundane beauty', 'life as it is', 'quiet narrative'],
        'found-family': ['bond', 'unrelated family', 'loyal companions', 'chosen family',
                        'support system', 'teamwork', 'squad', 'surrogate parents', 'emotional ties'],
        'road-trip': ['on the road', 'journey across', 'miles', 'car travel', 'hit the road',
                    'cross-country', 'travel companions', 'gas station', 'stopover', 'long drive'],
        'tech-noir': ['grim future', 'tech-savvy criminal', 'neon-lit', 'cyber corruption',
                    'urban decay', 'AI rebellion', 'cyberspace', 'digital heist', 'surveillance overload'],
        'folklore': ['legend', 'traditional tale', 'mythical creature', 'ancient lore',
                    'cultural story', 'spirit', 'oral tradition', 'forest demon', 'village tale']
    }

    def simple_tag_rule(text):
        text = text.lower()
        tags = set()
        for tag, keywords in rules.items():
            if any(word in text for word in keywords):
                tags.add(tag)
        return ', '.join(tags) if tags else np.nan

    # 10. 예측 실패 (nan)인 경우 규칙 기반으로 태그 보완
    no_tag_idx = test_df[test_df['predicted_tags'].isna()].index
    test_df.loc[no_tag_idx, 'predicted_tags'] = test_df.loc[no_tag_idx, 'text_input'].apply(simple_tag_rule)

    # 11. 원본에 태그 삽입
    df_2024_4.loc[test_df.index, 'tags'] = test_df['predicted_tags']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\675017308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['tags'] = df_2024_4['tags'].fillna('')
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\675017308.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['synopsis'] = df_2024_4['synopsis'].fillna('')
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\675017308.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['genre'] = df_2024_4['genre'].fillna('')
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\675017308.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['text_input'] = df_2024_4['synopsis'] + ' ' + df_2024_4['genre']

# %%
df_2024_4['tags'].value_counts(dropna=False)
# Out:
# tags
# drama                                                               219
# NaN                                                                 171
#  documentary                                                        159
# documentary                                                         114
#  based on true story,  lgbt,  short film, based on novel or book     98
#                                                                    ...
# twitter, meme                                                         1
# action, romance, drama, comedy, adventure                             1
# historical, sci-fi, romance, drama, family                            1
# underdog, superhero, rom-com, romance, drama, comedy, fantasy         1
# action, startup, sci-fi, drama, political                             1
# Name: count, Length: 7279, dtype: int64

# %% [markdown]
# # country에서 nan은 language와 같은 값으로 처리

# %%
df_2024_4.isnull().sum()
# Out:
# title                    0
# release_date             0
# type                     0
# runtime                  0
# season_count             0
# episode_count            0
# genre                    0
# director              1310
# cast                   630
# country                 10
# language                 0
# production_company    2569
# synopsis                 0
# tags                   171
# imdb_rating              0
# imdb_review_count        0
# text_input               0
# dtype: int64

# %%
df_2024_4['country'].fillna(df_2024_4['language'], inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\1580715248.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_2024_4['country'].fillna(df_2024_4['language'], inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\1580715248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['country'].fillna(df_2024_4['language'], inplace=True)

# %%
df_2024_4.isnull().sum()
# Out:
# title                    0
# release_date             0
# type                     0
# runtime                  0
# season_count             0
# episode_count            0
# genre                    0
# director              1310
# cast                   630
# country                  0
# language                 0
# production_company    2569
# synopsis                 0
# tags                   171
# imdb_rating              0
# imdb_review_count        0
# text_input               0
# dtype: int64

# %%
df_2024_4['production_company'].value_counts(dropna=False)
# Out:
# production_company
# NaN                                                              2569
# Vivamax                                                            75
# iQIYI                                                              39
# Youku                                                              21
# Tencent Video                                                      19
#                                                                  ...
# TBS Sparkle                                                         1
# Neeru Bajwa Entertainment                                           1
# EMOTION IS DEAD PTY LTD, Peter Williams TV, Stay Gold Studios       1
# Iconoclast, EDGLRD                                                  1
# Custom Production, Premier Studios, Yar&Ko                          1
# Name: count, Length: 7271, dtype: int64

# %% [markdown]
# # production_company, director, cast _is_comming 처리
# - 결측 값이 많아 이렇게 진행
# - 정보 부족이지 하나의 회사명, 이름은 x
# - 'unknown'만 삽입했을 경우 정상 값이라고 학습하는 것을 방지 => unknown으로 채우되 값은 없음으로 지정하기 위해 사용

# %%
unique_count = df_2024_4['production_company'].nunique(dropna=True)
print(unique_count)
# Out:
# 7270

# %%
df_2024_4['production_company_is_missing'] = df_2024_4['production_company'].isna().astype(int)
df_2024_4['production_company'] = df_2024_4['production_company'].fillna('unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\1483965936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['production_company_is_missing'] = df_2024_4['production_company'].isna().astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\1483965936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['production_company'] = df_2024_4['production_company'].fillna('unknown')

# %%
df_2024_4['cast_is_missing'] = df_2024_4['cast'].isna().astype(int)
df_2024_4['cast'] = df_2024_4['cast'].fillna('unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\819541931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['cast_is_missing'] = df_2024_4['cast'].isna().astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\819541931.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['cast'] = df_2024_4['cast'].fillna('unknown')

# %%
df_2024_4['director_is_missing'] = df_2024_4['director'].isna().astype(int)
df_2024_4['director'] = df_2024_4['director'].fillna('unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\4200672328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['director_is_missing'] = df_2024_4['director'].isna().astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_12364\4200672328.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2024_4['director'] = df_2024_4['director'].fillna('unknown')

# %%
print(df_2024_4.shape)
print(df_2024_4.isnull().sum())
# Out:
# (10858, 20)
# title                              0
# release_date                       0
# type                               0
# runtime                            0
# season_count                       0
# episode_count                      0
# genre                              0
# director                           0
# cast                               0
# country                            0
# language                           0
# production_company                 0
# synopsis                           0
# tags                             171
# imdb_rating                        0
# imdb_review_count                  0
# text_input                         0
# production_company_is_missing      0
# cast_is_missing                    0
# director_is_missing                0
# dtype: int64

# %%
nan_tags_rows = df_2024_4[df_2024_4['tags'].isna()]
nan_tags_rows
# Out:
#                                     title release_date   type  runtime  \
# 1197              Brotherhood of Blades 3   2024-04-20  movie    110.0
# 1445                   I Am Ready, Warden   2024-02-21  movie     37.0
# 1646                                Power   2024-05-10  movie     88.0
# 2356            Nosferatu: An Inside Look   2024-12-30  movie     22.0
# 2473                 Taken from Rio Bravo   2024-02-23  movie     80.0
# ...                                   ...          ...    ...      ...
# 16706                          Undisputed   2024-02-16     tv     41.0
# 16755                 Password - A jelszó   2024-12-31     tv     54.0
# 17048                         Rendez-vous   2024-01-14     tv     39.0
# 17882                       Pyjama partis   2024-05-13     tv     32.0
# 18876  Are You Being Bothered by the Bank   2024-02-19     tv     33.0
#
#        season_count  episode_count            genre          director  \
# 1197            1.0            1.0           Action      Jiang Xuanyi
# 1445            1.0            1.0      Documentary    Smriti Mundhra
# 1646            1.0            1.0      Documentary        Yance Ford
# 2356            1.0            1.0      Documentary           unknown
# 2473            1.0            1.0  Western, Action        Joe Cornet
# ...             ...            ...              ...               ...
# 16706           1.0            3.0      Documentary           unknown
# 16755           1.0            1.0             Talk           unknown
# 17048           1.0           22.0             News           unknown
# 17882           1.0            6.0             Talk           unknown
# 18876           1.0            4.0      Documentary  Anastasia Bezruk
#
#                                                     cast country language  \
# 1197         Leon Lee, Yang Yi, Yuen Cheung-Yan, Zu Kaer      CN       zh
# 1445   John Henry Ramirez, Aaron Castro, Jan Trujillo...      US       en
# 1646                                             unknown      US       en
# 2356   Robert Eggers, Nicholas Hoult, Lily-Rose Depp,...      US       en
# 2473   Alexander Nevsky, Cynthia Rothrock, Matthias H...      US       en
# ...                                                  ...     ...      ...
# 16706                         Ivan Cleary, Nathan Cleary      AU       en
# 16755                                  Ramóna Lékai-Kiss      HU       hu
# 17048                                 Christophe Deborsu      BE       fr
# 17882                                          Hugo Neyt      BE       fr
# 18876                                            unknown      RU       ru
#
#                                      production_company  \
# 1197                                            unknown
# 1445               Meralta Films, MTV Documentary Films
# 1646   Story Syndicate, Multitude Films, Corvidae Media
# 2356                                            unknown
# 2473                                    Hollywood Storm
# ...                                                 ...
# 16706                                           unknown
# 16755                           TV2 Hungary Media Group
# 17048                                       RTL Belgium
# 17882                                       RTL Belgium
# 18876        Custom Production, Premier Studios, Yar&Ko
#
#                                                 synopsis tags  imdb_rating  \
# 1197                                                      NaN          5.0
# 1445   In the days leading up to his execution, Texas...  NaN          6.4
# 1646   Driven to maintain social order, policing in t...  NaN          6.9
# 2356   An exclusive behind-the-scenes look “Nosferatu...  NaN         10.0
# 2473   1874, East Texas. Two friends pursue the Posse...  NaN          6.7
# ...                                                  ...  ...          ...
# 16706  Delve into the triumphs and challenges experie...  NaN          0.0
# 16755                                                     NaN          0.0
# 17048                                                     NaN          0.0
# 17882                                                     NaN          0.0
# 18876  Scammers make more than 8 million calls every ...  NaN          0.0
#
#        imdb_review_count                                         text_input  \
# 1197                   3                                             Action
# 1445                  19  In the days leading up to his execution, Texas...
# 1646                  12  Driven to maintain social order, policing in t...
# 2356                   1  An exclusive behind-the-scenes look “Nosferatu...
# 2473                  16  1874, East Texas. Two friends pursue the Posse...
# ...                  ...                                                ...
# 16706                  0  Delve into the triumphs and challenges experie...
# 16755                  0                                               Talk
# 17048                  0                                               News
# 17882                  0                                               Talk
# 18876                  0  Scammers make more than 8 million calls every ...
#
#        production_company_is_missing  cast_is_missing  director_is_missing
# 1197                               1                0                    0
# 1445                               0                0                    0
# 1646                               0                1                    0
# 2356                               1                0                    1
# 2473                               0                0                    0
# ...                              ...              ...                  ...
# 16706                              1                0                    1
# 16755                              0                0                    1
# 17048                              0                0                    1
# 17882                              0                0                    1
# 18876                              0                1                    0
#
# [171 rows x 20 columns]

# %%
df_2024_5 = df_2024_4[df_2024_4['tags'].notna()].copy()
df_2024_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10687 entries, 0 to 19616
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   title                          10687 non-null  object
#  1   release_date                   10687 non-null  object
#  2   type                           10687 non-null  object
#  3   runtime                        10687 non-null  float64
#  4   season_count                   10687 non-null  float64
#  5   episode_count                  10687 non-null  float64
#  6   genre                          10687 non-null  object
#  7   director                       10687 non-null  object
#  8   cast                           10687 non-null  object
#  9   country                        10687 non-null  object
#  10  language                       10687 non-null  object
#  11  production_company             10687 non-null  object
#  12  synopsis                       10687 non-null  object
#  13  tags                           10687 non-null  object
#  14  imdb_rating                    10687 non-null  float64
#  15  imdb_review_count              10687 non-null  int64
#  16  text_input                     10687 non-null  object
#  17  production_company_is_missing  10687 non-null  int32
#  18  cast_is_missing                10687 non-null  int32
#  19  director_is_missing            10687 non-null  int32
# dtypes: float64(4), int32(3), int64(1), object(12)
# memory usage: 1.6+ MB

# %%
df_2024_5.to_csv('전처리_완료(csv)/2024년도 전처리.csv', index=False)
